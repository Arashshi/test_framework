# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2 align="center"style="color: black;">Machine Learning-based Algorithmic Trading</h2>
#     <h3 align="center"style="color: black;">Walk Forward Backtest Experiment</h3>
#     <h5 align="center"style="color: black;">Week 5 Day 1</h5>
#     <h5 align="center"style="color: black;"><em>Mohammad Talaei</em></h5>
# </div>

# %% [markdown]
# # Kaggle services and tools

# %%
# !pip install feature_engine
# !pip install colorlog
# Out:
# Requirement already satisfied: feature_engine in /usr/local/lib/python3.10/dist-packages (1.8.1)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (1.5.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.0->feature_engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.0->feature_engine) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.0->feature_engine) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.0->feature_engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.0->feature_engine) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.11.1->feature_engine) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.11.1->feature_engine) (24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.11.1->feature_engine) (1.16.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (6.8.2)

# %%
# !pip show xgboost
# Out:
# Name: xgboost
# Version: 2.1.1
# Summary: XGBoost Python Package
# Home-page:
# Author:
# Author-email: Hyunsu Cho <chohyu01@cs.washington.edu>, Jiaming Yuan <jm.yuan@outlook.com>
# License: Apache-2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, nvidia-nccl-cu12, scipy
# Required-by:

# %%
model_type = 'XGB' #@param ['XGB', 'RF', 'LGBM'] {type: "string"}
MANUAL_EXP = True #@param {type:"boolean"}

# %%
print(MANUAL_EXP)
# Out:
# True

# %% [markdown]
# # Weights & Biase
#
# ![ChessUrl](https://docs.wandb.ai/assets/images/wandb_demo_experiments-4797af7fe7236d6c5c42adbdc93deb4c.gif "chess")
#
# Steps:
# - Create a W&B account [wandb.ai](https://wandb.ai/)
# - Read docs [W&B docs](https://docs.wandb.ai/)
# - Install using pip:  `!pip install wandb`
# - Get API token [link](https://wandb.ai/authorize)
# - Create a secret or an env variable for the token

# %%
import wandb
from google.colab import userdata
secret_value = userdata.get('wandb_token')
wandb.login(key=secret_value)

api = wandb.Api()
# Out:
# wandb: Currently logged in as: amirhosseinfarahani (alpha-hunters). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: amirhosseinfarahani (alpha-hunters). Use `wandb login --relogin` to force relogin

# %% [markdown]
# # Read functions from the GitHub repo
#
# - GitHub account and repo
# - Generate an access token on your GitHub account [Link](https://github.com/settings/tokens)
# - Then make a secret or an environment variable to use it

# %%
import sys
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
token = userdata.get("GITHUB_TOKEN")
# !rm -r ./ML-Algotrading-Project
# !git clone https://{token}@github.com/AmirhsFar/ML-Algotrading-Project.git
# !pip install -r ./ML-Algotrading-Project/dataset/requirements.txt
sys.path.append("/content/ML-Algotrading-Project")
print('All done')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Cloning into 'ML-Algotrading-Project'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 214 (delta 127), reused 156 (delta 72), pack-reused 0 (from 0)
# Receiving objects: 100% (214/214), 2.12 MiB | 19.17 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# Collecting aiohappyeyeballs==2.4.0 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 1))
#   Using cached aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp==3.10.5 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 2))
#   Using cached aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: aiosignal==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 3)) (1.3.1)
# Collecting asttokens==2.4.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 4))
#   Using cached asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: attrs==24.2.0 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 5)) (24.2.0)
# Collecting colorama==0.4.6 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 6))
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorlog==6.8.2 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 7)) (6.8.2)
# Collecting comm==0.2.2 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 8))
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy==1.8.5 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 9))
#   Using cached debugpy-1.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 10))
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting executing==2.1.0 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 11))
#   Using cached executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: frozenlist==1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: feature_engine==1.8.1 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 13)) (1.8.1)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 14)) (3.10)
# Collecting ipykernel==6.29.5 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 15))
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.27.0 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 16))
#   Using cached ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting jedi==0.19.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 17))
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting jupyter_client==8.6.3 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 18))
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter_core==5.7.2 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 19)) (5.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 20)) (0.1.7)
# ERROR: Could not find a version that satisfies the requirement MetaTrader5==5.0.4424 (from versions: none)
# ERROR: No matching distribution found for MetaTrader5==5.0.4424
# All done

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from dataset.configs.feature_configs_general import generate_general_config
from dataset.dukascopy_func import (
    crawl_OHLCV_data_dukascopy
)
from dataset.history_data_stage_one_func import (
    history_data_stage_one
)
from dataset.realtime_candle_func import (
    historiy_realtime_candle
)
from dataset.indicator_func import history_indicator_calculator
from dataset.realtime_shift_func import history_cndl_shift
from dataset.create_basic_features_func import (
    history_basic_features,
    history_fe_market_close,
    history_fe_time
)
from dataset.window_agg_features_func import (
    history_fe_WIN_features
)
from dataset.columns_merge_func import history_columns_merge
# from dataset.data_crawlers.metatrader_func import (
#     crawl_OHLCV_data_metatrader,
# )
from main_func import main
# from forex_MLOps.utils.wandb_utils import read_obj
from ETL import read_data_manual, ETL
# from forex_MLOps.model_ensemble import QuantEnsemble
from utils.wandb_utils import (
    fetch_artifacts, read_tracker_objects, download_wandb_artifact
)
########### READ DATA MANUALLY #########
# df_all = read_data_manual()
# !tail -n 120 ./forex_MLOps/ETL.py

# %% [markdown]
# # 0. Data Fetching & Preprocessing

# %% [markdown]
# ## Dukascopy

# %%
config_general = generate_general_config()
failed_dates_dict = await crawl_OHLCV_data_dukascopy(
    feature_config = config_general
)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
# INFO:test run:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
#   [test run][INFO]:--> number of days ALL in time range: 668
# INFO:test run:--> number of days ALL in time range: 668
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
# INFO:test run:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-10-29 00:00:00
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
#   [test run][INFO]:==============================
# INFO:test run:==============================
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
#   [test run][INFO]:--> EURUSD
# INFO:test run:--> EURUSD
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
# INFO:test run:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/09/29/BID_candles_min_1.bi5
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
#   [test run][INFO]:--> df.shape: (960480, 6)
# INFO:test run:--> df.shape: (960480, 6)
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
# INFO:test run:--> faild_dates: [datetime.datetime(2024, 10, 29, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> fEURUSD run-time: 138.57 seconds
# INFO:test run:--> fEURUSD run-time: 138.57 seconds
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
# INFO:test run:--> crawl_OHLCV_data_dukascopy successfully.

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/raw_data/dukascopy/EURUSD_dukascopy.parquet"
)
df.iloc[[1000, 1006, 11012]]
# Out:
#                           _time     open     high      low    close  \
# 1000  2023-01-04 11:20:00+00:00  1.06179  1.06188  1.06151  1.06173
# 1006  2023-01-04 11:50:00+00:00  1.06038  1.06079  1.06021  1.06063
# 11012 2023-02-08 05:40:00+00:00  1.07294  1.07295  1.07280  1.07290
#
#        tick_volume data_source  symbol
# 1000    671.040009   dukascopy  EURUSD
# 1006    665.929993   dukascopy  EURUSD
# 11012   207.729996   dukascopy  EURUSD

# %% [markdown]
# ## Metatrader 5
#
# Do this section in your system and place the `.parquet` file in *dataset\data\raw_data\metatrader*, then reclone the repository and proceed for the furthur steps.

# %% [markdown]
# ## Creating Stage-One Data

# %%
history_data_stage_one(config_general)
# Out:
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
#   [test run][INFO]:--> start history_data_stage_one fumc:
# INFO:test run:--> start history_data_stage_one fumc:
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
#   [test run][INFO]:-------------------------
# INFO:test run:-------------------------
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
#   [test run][INFO]:--> symbol:EURUSD
# INFO:test run:--> symbol:EURUSD
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> number of nulls before forward fill: 0
# INFO:test run:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
# INFO:test run:--> min time: 2023-01-03 00:00:00, max time: 2024-10-29 02:55:00
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
# INFO:test run:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
#   [test run][INFO]:--> history_data_stage_one run successfully.
# INFO:test run:--> history_data_stage_one run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/stage_one_data/EURUSD_stage_one.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 120000]]
# Out:
#                      _time     open     high      low    close  tick_volume  \
# 1      2023-01-03 00:05:00  1.06648  1.06650  1.06646  1.06650    15.320000
# 5      2023-01-03 00:25:00  1.06652  1.06652  1.06649  1.06652    10.800000
# 1000   2023-01-06 11:20:00  1.05131  1.05133  1.04965  1.05060  2732.000031
# 2006   2023-01-11 23:10:00  1.07557  1.07557  1.07542  1.07550   399.619991
# 11012  2023-02-24 05:40:00  1.06029  1.06030  1.06015  1.06015   494.959991
# 120000 2024-08-07 16:00:00  1.09215  1.09224  1.09181  1.09197   465.000000
#
#        data_source  was_ffilled       _date
# 1        dukascopy        False  2023-01-03
# 5        dukascopy        False  2023-01-03
# 1000     dukascopy        False  2023-01-06
# 2006     dukascopy        False  2023-01-11
# 11012    dukascopy        False  2023-02-24
# 120000  metatrader        False  2024-08-07

# %% [markdown]
# ## Creating Real-Time Candles

# %%
historiy_realtime_candle(config_general)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
# INFO:test run:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
#   [test run][INFO]:symbol: EURUSD
# INFO:test run:symbol: EURUSD
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
#   [test run][INFO]:--> EURUSD saved.
# INFO:test run:--> EURUSD saved.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
# INFO:test run:--> historiy_realtime_candle run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/realtime_candle/EURUSD_realtime_candle.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  index  M5_OPEN  M5_CLOSE   M5_LOW  M5_HIGH  \
# 1     2023-01-03 00:05:00      1  1.06648   1.06650  1.06646  1.06650
# 5     2023-01-03 00:25:00      5  1.06652   1.06652  1.06649  1.06652
# 1000  2023-01-06 11:20:00   1000  1.05131   1.05060  1.04965  1.05133
# 2006  2023-01-11 23:10:00   2006  1.07557   1.07550  1.07542  1.07557
# 11012 2023-02-24 05:40:00  11012  1.06029   1.06015  1.06015  1.06030
# 20000 2023-04-10 10:40:00  20000  1.09085   1.09088  1.09079  1.09094
#
#          M5_VOLUME       _date  minutesPassed  isFirst  M15_OPEN  M15_HIGH  \
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_SMA
# !!! fe_EMA_M5_CLOSE_W60_cndl_M5_norm not in df.columns or fe_EMA_M5_CLOSE_W366_cndl_M5_norm not in df.columns.
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
# INFO:test run:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--> fe_SMA_EURUSD done.
# INFO:test run:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
# INFO:test run:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--> fe_ATR_EURUSD done.
# INFO:test run:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
# INFO:test run:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
# INFO:test run:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
# INFO:test run:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
# INFO:test run:--> history_indicator_calculator run successfully.

# %% [markdown]
# **ATR**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_ATR/fe_ATR_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_ATR_M60_W14_cndl_M60  fe_ATR_M60_W30_cndl_M60  \
# 1     2023-01-10 04:00:00                18.071429                16.603333
# 5     2023-01-10 04:20:00                18.071429                16.603333
# 1000  2023-01-13 15:15:00                17.428571                22.846667
# 2006  2023-01-19 03:05:00                22.378571                19.843333
# 11012 2023-03-03 09:35:00                10.450000                13.646667
# 20000 2023-04-17 14:35:00                12.542857                14.980000
#
#        fe_ATR_M60_W7_cndl_M60  fe_ATR_M240_W14_cndl_M240  \
# 1                   12.600000                  40.957143
# 5                   12.600000                  40.957143
# 1000                21.600000                  38.900000
# 2006                 8.871429                  41.635714
# 11012                9.500000                  31.221429
# 20000               15.057143                  31.078571
#
#        fe_ATR_M240_W7_cndl_M240  fe_ATR_M240_W30_cndl_M240  symbol
# 1                     36.228571                  43.630000  EURUSD
# 5                     36.228571                  43.630000  EURUSD
# 1000                  48.885714                  39.236667  EURUSD
# 2006                  47.628571                  42.166667  EURUSD
# 11012                 27.985714                  30.186667  EURUSD
# 20000                 35.128571                  29.553333  EURUSD

# %% [markdown]
# **RSTD**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_RSTD/fe_RSTD_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_RSTD_M240_CLOSE_W14_cndl_M240  \
# 1     2023-01-10 04:00:00                         28.851866
# 5     2023-01-10 04:20:00                         28.851866
# 1000  2023-01-13 15:15:00                         17.349237
# 2006  2023-01-19 03:05:00                         33.624757
# 11012 2023-03-03 09:35:00                         20.490879
# 20000 2023-04-17 14:35:00                         21.546791
#
#        fe_RSTD_M240_CLOSE_W7_cndl_M240  fe_RSTD_M240_CLOSE_W30_cndl_M240  \
# 1                            22.196076                         33.800598
# 5                            22.196076                         33.800598
# 1000                         23.693676                         22.990681
# 2006                         42.221738                         29.125541
# 11012                        17.424743                         19.887670
# 20000                        22.011785                         21.233008
#
#        symbol
# 1      EURUSD
# 5      EURUSD
# 1000   EURUSD
# 2006   EURUSD
# 11012  EURUSD
# 20000  EURUSD

# %% [markdown]
# **ratio**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_ratio/fe_ratio_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_ratio_RSI_M5_CLOSE_W7_W14_cndl_M5  \
# 1     2023-01-10 04:00:00                               1.10364
# 5     2023-01-10 04:20:00                               1.07202
# 1000  2023-01-13 15:15:00                               1.21804
# 2006  2023-01-19 03:05:00                               1.07378
# 11012 2023-03-03 09:35:00                               0.92585
# 20000 2023-04-17 14:35:00                               0.71864
#
#        fe_ratio_RSI_M5_CLOSE_W7_W30_cndl_M5  \
# 1                                   1.24858
# 5                                   1.22618
# 1000                                1.29301
# 2006                                1.13642
# 11012                               0.89426
# 20000                               0.64987
#
#        fe_ratio_RSI_M60_CLOSE_W7_W14_cndl_M60  \
# 1                                     0.92447
# 5                                     0.92447
# 1000                                  0.66147
# 2006                                  0.85202
# 11012                                 1.24219
# 20000                                 1.09720
#
#        fe_ratio_RSI_M60_CLOSE_W7_W30_cndl_M60  \
# 1                                     0.93830
# 5                                     0.93830
# 1000                                  0.56106
# 2006                                  0.78994
# 11012                                 1.32987
# 20000                                 1.02517
#
#        fe_ratio_RSI_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                       1.09920
# 5                                       1.09920
# 1000                                    1.01861
# 2006                                    0.90326
# 11012                                   0.97893
# 20000                                   0.77015
#
#        fe_ratio_RSI_M240_CLOSE_W7_W30_cndl_M240  \
# 1                                       1.21066
# 5                                       1.21066
# 1000                                    1.10077
# 2006                                    0.82459
# 11012                                   1.00778
# 20000                                   0.68171
#
#        fe_ratio_EMA_M5_CLOSE_W7_W60_cndl_M5  \
# 1                                   0.18333
# 5                                   0.21334
# 1000                               -0.09465
# 2006                               -9.42515
# 11012                              -0.04950
# 20000                               0.36801
#
#        fe_ratio_EMA_M5_CLOSE_W60_W1440_cndl_M5  \
# 1                                      0.03184
# 5                                      0.05710
# 1000                                  -0.22112
# 2006                                   0.05142
# 11012                                  3.04681
# 20000                                  1.39218
#
#        fe_ratio_SMA_M5_CLOSE_W240_W720_cndl_M5  \
# 1                                      0.16447
# 5                                      0.18357
# 1000                                  -1.22493
# 2006                                   1.12334
# 11012                                 -2.85007
# 20000                                  0.22549
#
#        fe_ratio_SMA_M5_CLOSE_W480_W720_cndl_M5  \
# 1                                      0.60573
# 5                                      0.60716
# 1000                                   0.20129
# 2006                                   0.77905
# 11012                                  1.77848
# 20000                                  0.99245
#
#        fe_ratio_ATR_M60_CLOSE_W7_W14_cndl_M60  \
# 1                                     0.69723
# 5                                     0.69723
# 1000                                  1.23934
# 2006                                  0.39643
# 11012                                 0.90909
# 20000                                 1.20046
#
#        fe_ratio_ATR_M60_CLOSE_W7_W30_cndl_M60  \
# 1                                     0.75888
# 5                                     0.75888
# 1000                                  0.94543
# 2006                                  0.44707
# 11012                                 0.69614
# 20000                                 1.00515
#
#        fe_ratio_ATR_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                       0.88455
# 5                                       0.88455
# 1000                                    1.25670
# 2006                                    1.14394
# 11012                                   0.89636
# 20000                                   1.13031
#
#        fe_ratio_ATR_M240_CLOSE_W7_W30_cndl_M240  \
# 1                                       0.83036
# 5                                       0.83036
# 1000                                    1.24592
# 2006                                    1.12953
# 11012                                   0.92709
# 20000                                   1.18865
#
#        fe_ratio_RSTD_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                        0.76931
# 5                                        0.76931
# 1000                                     1.36569
# 2006                                     1.25567
# 11012                                    0.85037
# 20000                                    1.02158
#
#        fe_ratio_RSTD_M240_CLOSE_W7_W30_cndl_M240  symbol
# 1                                        0.65668  EURUSD
# 5                                        0.65668  EURUSD
# 1000                                     1.03058  EURUSD
# 2006                                     1.44965  EURUSD
# 11012                                    0.87616  EURUSD
# 20000                                    1.03668  EURUSD

# %% [markdown]
# **SMA**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_SMA/fe_SMA_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_SMA_M5_CLOSE_W480_cndl_M5_norm  \
# 1     2023-01-05 12:05:00                         -23.898542
# 5     2023-01-05 12:25:00                         -23.515000
# 1000  2023-01-10 23:20:00                         -12.696042
# 2006  2023-01-16 11:10:00                          30.616667
# 11012 2023-02-28 17:40:00                         -39.848333
# 20000 2023-04-12 22:40:00                         -62.511667
#
#        fe_SMA_M5_CLOSE_W240_cndl_M5_norm  fe_SMA_M5_CLOSE_W720_cndl_M5_norm  \
# 1                              -7.779167                         -19.095972
# 5                              -7.900417                         -19.553472
# 1000                           -2.746667                         -51.889861
# 2006                           25.888333                           7.948056
# 11012                         -19.715417                         -45.524028
# 20000                         -42.127917                         -81.302361
#
#        symbol
# 1      EURUSD
# 5      EURUSD
# 1000   EURUSD
# 2006   EURUSD
# 11012  EURUSD
# 20000  EURUSD

# %% [markdown]
# **RSI**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_RSI/fe_RSI_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_RSI_M60_CLOSE_W14_cndl_M60  \
# 1     2023-01-10 04:00:00                      64.267715
# 5     2023-01-10 04:20:00                      64.267715
# 1000  2023-01-13 15:15:00                      44.888632
# 2006  2023-01-19 03:05:00                      42.979763
# 11012 2023-03-03 09:35:00                      54.838257
# 20000 2023-04-17 14:35:00                      42.936395
#
#        fe_RSI_M60_CLOSE_W14_gte_70_cndl_M60  \
# 1                                     False
# 5                                     False
# 1000                                  False
# 2006                                  False
# 11012                                 False
# 20000                                 False
#
#        fe_RSI_M60_CLOSE_W14_lte_30_cndl_M60  fe_RSI_M5_CLOSE_W7_cndl_M5  \
# 1                                     False                   67.008366
# 5                                     False                   69.474144
# 1000                                  False                   53.523362
# 2006                                  False                   56.601702
# 11012                                 False                   50.922419
# 20000                                 False                   29.227274
#
#        fe_RSI_M5_CLOSE_W7_gte_70_cndl_M5  fe_RSI_M5_CLOSE_W7_lte_30_cndl_M5  \
# 1                                  False                              False
# 5                                  False                              False
# 1000                               False                              False
# 2006                               False                              False
# 11012                              False                              False
# 20000                              False                               True
#
#        fe_RSI_M60_CLOSE_W30_cndl_M60  fe_RSI_M60_CLOSE_W30_gte_70_cndl_M60  \
# 1                          63.320560                                 False
# 5                          63.320560                                 False
# 1000                       52.922225                                 False
# 2006                       46.357422                                 False
# 11012                      51.222783                                 False
# 20000                      45.953516                                 False
#
#        fe_RSI_M60_CLOSE_W30_lte_30_cndl_M60  fe_RSI_M240_CLOSE_W7_cndl_M240  \
# 1                                     False                       75.481220
# 5                                     False                       75.481220
# 1000                                  False                       74.815001
# 2006                                  False                       43.463978
# 11012                                 False                       48.155659
# 20000                                 False                       35.754040
#
#        fe_RSI_M240_CLOSE_W7_gte_70_cndl_M240  \
# 1                                       True
# 5                                       True
# 1000                                    True
# 2006                                   False
# 11012                                  False
# 20000                                  False
#
#        fe_RSI_M240_CLOSE_W7_lte_30_cndl_M240  fe_RSI_M240_CLOSE_W30_cndl_M240  \
# 1                                      False                        62.347311
# 5                                      False                        62.347311
# 1000                                   False                        67.966007
# 2006                                   False                        52.709877
# 11012                                  False                        47.784069
# 20000                                  False                        52.447879
#
#        fe_RSI_M240_CLOSE_W30_gte_70_cndl_M240  \
# 1                                       False
# 5                                       False
# 1000                                    False
# 2006                                    False
# 11012                                   False
# 20000                                   False
#
#        fe_RSI_M240_CLOSE_W30_lte_30_cndl_M240  fe_RSI_M5_CLOSE_W30_cndl_M5  \
# 1                                       False                    53.667595
# 5                                       False                    56.658967
# 1000                                    False                    41.394286
# 2006                                    False                    49.807106
# 11012                                   False                    56.943621
# 20000                                   False                    44.974307
#
#        fe_RSI_M5_CLOSE_W30_gte_70_cndl_M5  fe_RSI_M5_CLOSE_W30_lte_30_cndl_M5  \
# 1                                   False                               False
# 5                                   False                               False
# 1000                                False                               False
# 2006                                False                               False
# 11012                               False                               False
# 20000                               False                               False
#
#        fe_RSI_M240_CLOSE_W14_cndl_M240  \
# 1                            68.669294
# 5                            68.669294
# 1000                         73.448419
# 2006                         48.118779
# 11012                        49.192361
# 20000                        46.425033
#
#        fe_RSI_M240_CLOSE_W14_gte_70_cndl_M240  \
# 1                                       False
# 5                                       False
# 1000                                     True
# 2006                                    False
# 11012                                   False
# 20000                                   False
#
#        fe_RSI_M240_CLOSE_W14_lte_30_cndl_M240  fe_RSI_M60_CLOSE_W7_cndl_M60  \
# 1                                       False                     59.413433
# 5                                       False                     59.413433
# 1000                                    False                     29.692562
# 2006                                    False                     36.619519
# 11012                                   False                     68.119519
# 20000                                   False                     47.109967
#
#        fe_RSI_M60_CLOSE_W7_gte_70_cndl_M60  \
# 1                                    False
# 5                                    False
# 1000                                 False
# 2006                                 False
# 11012                                False
# 20000                                False
#
#        fe_RSI_M60_CLOSE_W7_lte_30_cndl_M60  fe_RSI_M5_CLOSE_W14_cndl_M5  \
# 1                                    False                    60.715630
# 5                                    False                    64.806664
# 1000                                  True                    43.942078
# 2006                                 False                    52.712556
# 11012                                False                    55.000955
# 20000                                False                    40.670144
#
#        fe_RSI_M5_CLOSE_W14_gte_70_cndl_M5  fe_RSI_M5_CLOSE_W14_lte_30_cndl_M5  \
# 1                                   False                               False
# 5                                   False                               False
# 1000                                False                               False
# 2006                                False                               False
# 11012                               False                               False
# 20000                               False                               False
#
#        symbol
# 1      EURUSD
# 5      EURUSD
# 1000   EURUSD
# 2006   EURUSD
# 11012  EURUSD
# 20000  EURUSD

# %% [markdown]
# **EMA**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_EMA/fe_EMA_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20
# 35000       1.09277     1.09167       1.09277      1.09127      1.09336
# 70000       1.07953     1.07915       1.07921      1.07927      1.07969
# 120000      1.09220     1.09131       1.09215      1.09229      1.09253
#
#         M60_LOW_-1  M60_CLOSE_-1  M240_OPEN_-1  M240_HIGH_-1  M240_LOW_-1  \
# 1          1.06645       1.06648       1.06646       1.06649      1.06645
# 5          1.06645       1.06648       1.06646       1.06649      1.06645
# 1000       1.05109       1.05183       1.05250       1.05363      1.05105
# 2006       1.07523       1.07537       1.07498       1.07762      1.07362
# 11012      1.05946       1.05969       1.05934       1.06141      1.05927
# 20000      1.08952       1.09048       1.09034       1.09066      1.08951
# 35000      1.09093       1.09248       1.09161       1.09336      1.09058
# 70000      1.07888       1.07921       1.08132       1.08133      1.07902
# 120000     1.09131       1.09215       1.09184       1.09262      1.09081
#
#         M240_CLOSE_-1  M1440_OPEN_-1  M1440_HIGH_-1  M1440_LOW_-1  \
# 1             1.06648        1.06646        1.06649       1.06645
# 5             1.06648        1.06646        1.06649       1.06645
# 1000          1.05142        1.06006        1.06314       1.05148
# 2006          1.07465        1.07293        1.07592       1.07119
# 11012         1.06010        1.06031        1.06275       1.05769
# 20000         1.08962        1.09196        1.09240       1.08762
# 35000         1.09248        1.09201        1.09461       1.08921
# 70000         1.07929        1.07635        1.08171       1.07548
# 120000        1.09215        1.09512        1.09627       1.09034
#
#         M1440_CLOSE_-1
# 1              1.06648
# 5              1.06648
# 1000           1.05202
# 2006           1.07322
# 11012          1.05949
# 20000          1.09029
# 35000          1.09173
# 70000          1.07929
# 120000         1.09296

# %% [markdown]
# ### C) Candle & Time Features

# %%
history_basic_features(config_general)
history_fe_market_close(config_general)
history_fe_time(config_general)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
#   [test run][INFO]:--> start history_basic_features fumc:
# INFO:test run:--> start history_basic_features fumc:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl, EURUSD:
# INFO:test run:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
#   [test run][INFO]:--> fe_cndl EURUSD saved.
# INFO:test run:--> fe_cndl EURUSD saved.
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
# INFO:test run:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
# INFO:test run:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
#   [test run][INFO]:--> history_basic_features run successfully.
# INFO:test run:--> history_basic_features run successfully.
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
#   [test run][INFO]:--> start history_fe_market_close fumc:
# INFO:test run:--> start history_fe_market_close fumc:
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
#   [test run][INFO]:-->EURUSD
# INFO:test run:-->EURUSD
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
#   [test run][INFO]:--> history_fe_market_close run successfully.
# INFO:test run:--> history_fe_market_close run successfully.
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
#   [test run][INFO]:--> start history_fe_time fumc:
# INFO:test run:--> start history_fe_time fumc:
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
# INFO:test run:--> history_fe_time run successfully.

# %% [markdown]
# **Candle Shift**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_cndl_shift/fe_cndl_shift_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time
# 70000                            0.00038                             0.00032
# 120000                           0.00089                             0.00005
#
#         fe_cndl_shift_M30_HIGH_to_OPEN_-1  fe_cndl_shift_M30_OPEN_to_LOW_-1  \
# 1                                 0.00003                           0.00001
# 5                                 0.00003                           0.00001
# 1000                              0.00077                           0.00032
# 2006                              0.00014                           0.00052
# 11012                             0.00081                           0.00001
# 20000                             0.00065                           0.00008
# 35000                             0.00028                           0.00082
# 70000                             0.00032                           0.00006
# 120000                            0.00079                           0.00010
#
#         fe_cndl_shift_M30_CLOSE_to_LOW_-1  fe_cndl_shift_M60_CLOSE_to_OPEN_-1  \
# 1                                 0.00003                             0.00002
# 5                                 0.00003                             0.00002
# 1000                              0.00028                             0.00057
# 2006                              0.00014                            -0.00092
# 11012                             0.00070                            -0.00041
# 20000                             0.00029                             0.00054
# 35000                             0.00110                             0.00121
# 70000                             0.00006                            -0.00006
# 120000                            0.00084                            -0.00014
#
#         fe_cndl_shift_M60_HIGH_to_LOW_-1  fe_cndl_shift_M60_HIGH_to_CLOSE_-1  \
# 1                                0.00004                             0.00001
# 5                                0.00004                             0.00001
# 1000                             0.00200                             0.00126
# 2006                             0.00106                             0.00092
# 11012                            0.00115                             0.00092
# 20000                            0.00102                             0.00006
# 35000                            0.00243                             0.00088
# 70000                            0.00081                             0.00048
# 120000                           0.00122                             0.00038
#
#         fe_cndl_shift_M60_HIGH_to_OPEN_-1  fe_cndl_shift_M60_OPEN_to_LOW_-1  \
# 1                                 0.00003                           0.00001
# 5                                 0.00003                           0.00001
# 1000                              0.00183                           0.00017
# 2006                              0.00000                           0.00106
# 11012                             0.00051                           0.00064
# 20000                             0.00060                           0.00042
# 35000                             0.00209                           0.00034
# 70000                             0.00042                           0.00039
# 120000                            0.00024                           0.00098
#
#         fe_cndl_shift_M60_CLOSE_to_LOW_-1  \
# 1                                 0.00003
# 5                                 0.00003
# 1000                              0.00074
# 2006                              0.00014
# 11012                             0.00023
# 20000                             0.00096
# 35000                             0.00155
# 70000                             0.00033
# 120000                            0.00084
#
#         fe_cndl_shift_M240_CLOSE_to_OPEN_-1  \
# 1                                   0.00002
# 5                                   0.00002
# 1000                               -0.00108
# 2006                               -0.00033
# 11012                               0.00076
# 20000                              -0.00072
# 35000                               0.00087
# 70000                              -0.00203
# 120000                              0.00031
#
#         fe_cndl_shift_M240_HIGH_to_LOW_-1  \
# 1                                 0.00004
# 5                                 0.00004
# 1000                              0.00258
# 2006                              0.00400
# 11012                             0.00214
# 20000                             0.00115
# 35000                             0.00278
# 70000                             0.00231
# 120000                            0.00181
#
#         fe_cndl_shift_M240_HIGH_to_CLOSE_-1  \
# 1                                   0.00001
# 5                                   0.00001
# 1000                                0.00221
# 2006                                0.00297
# 11012                               0.00131
# 20000                               0.00104
# 35000                               0.00088
# 70000                               0.00204
# 120000                              0.00047
#
#         fe_cndl_shift_M240_HIGH_to_OPEN_-1  fe_cndl_shift_M240_OPEN_to_LOW_-1  \
# 1                                  0.00003                            0.00001
# 5                                  0.00003                            0.00001
# 1000                               0.00113                            0.00145
# 2006                               0.00264                            0.00136
# 11012                              0.00207                            0.00007
# 20000                              0.00032                            0.00083
# 35000                              0.00175                            0.00103
# 70000                              0.00001                            0.00230
# 120000                             0.00078                            0.00103
#
#         fe_cndl_shift_M240_CLOSE_to_LOW_-1  \
# 1                                  0.00003
# 5                                  0.00003
# 1000                               0.00037
# 2006                               0.00103
# 11012                              0.00083
# 20000                              0.00011
# 35000                              0.00190
# 70000                              0.00027
# 120000                             0.00134
#
#         fe_cndl_shift_M1440_CLOSE_to_OPEN_-1  \
# 1                                    0.00002
# 5                                    0.00002
# 1000                                -0.00804
# 2006                                 0.00029
# 11012                               -0.00082
# 20000                               -0.00167
# 35000                               -0.00028
# 70000                                0.00294
# 120000                              -0.00216
#
#         fe_cndl_shift_M1440_HIGH_to_LOW_-1  \
# 1                                  0.00004
# 5                                  0.00004
# 1000                               0.01166
# 2006                               0.00473
# 11012                              0.00506
# 20000                              0.00478
# 35000                              0.00540
# 70000                              0.00623
# 120000                             0.00593
#
#         fe_cndl_shift_M1440_HIGH_to_CLOSE_-1  \
# 1                                    0.00001
# 5                                    0.00001
# 1000                                 0.01112
# 2006                                 0.00270
# 11012                                0.00326
# 20000                                0.00211
# 35000                                0.00288
# 70000                                0.00242
# 120000                               0.00331
#
#         fe_cndl_shift_M1440_HIGH_to_OPEN_-1  \
# 1                                   0.00003
# 5                                   0.00003
# 1000                                0.00308
# 2006                                0.00299
# 11012                               0.00244
# 20000                               0.00044
# 35000                               0.00260
# 70000                               0.00536
# 120000                              0.00115
#
#         fe_cndl_shift_M1440_OPEN_to_LOW_-1  \
# 1                                  0.00001
# 5                                  0.00001
# 1000                               0.00858
# 2006                               0.00174
# 11012                              0.00262
# 20000                              0.00434
# 35000                              0.00280
# 70000                              0.00087
# 120000                             0.00478
#
#         fe_cndl_shift_M1440_CLOSE_to_LOW_-1  symbol
# 1                                   0.00003  EURUSD
# 5                                   0.00003  EURUSD
# 1000                                0.00054  EURUSD
# 2006                                0.00203  EURUSD
# 11012                               0.00180  EURUSD
# 20000                               0.00267  EURUSD
# 35000                               0.00252  EURUSD
# 70000                               0.00381  EURUSD
# 120000                              0.00262  EURUSD

# %% [markdown]
# **Market Close**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_market_close/fe_market_close_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time  fe_market_close_New_York  \
# 1      2023-01-04 00:00:00                       0.3
# 5      2023-01-04 00:20:00                       0.3
# 1000   2023-01-09 11:15:00                      35.0
# 2006   2023-01-12 23:05:00                      97.2
# 11012  2023-02-27 05:35:00                      -4.0
# 20000  2023-04-11 10:35:00                      35.0
# 35000  2023-06-22 12:35:00                      15.5
# 70000  2023-12-11 01:15:00                       5.3
# 120000 2024-08-08 15:55:00                     -24.0
#
#         fe_market_close_New_York_time  fe_market_close_Tokyo  \
# 1                                 5.0                   -4.8
# 5                                25.0                   -4.8
# 1000                            680.0                  -13.8
# 2006                           1390.0                  105.4
# 11012                           340.0                  -47.7
# 20000                           640.0                  -21.9
# 35000                           760.0                    7.1
# 70000                            80.0                  -24.5
# 120000                          960.0                  -42.4
#
#         fe_market_close_Tokyo_time  fe_market_close_Sydney  \
# 1                            785.0                  -120.3
# 5                            805.0                  -120.3
# 1000                          20.0                    -0.1
# 2006                         730.0                    81.8
# 11012                       1120.0                   -58.8
# 20000                       1420.0                    13.2
# 35000                        100.0                     8.5
# 70000                        860.0                   -18.2
# 120000                       300.0                   -37.5
#
#         fe_market_close_Sydney_time  fe_market_close_London  \
# 1                            1025.0                    -8.5
# 5                            1045.0                    -8.5
# 1000                          260.0                    74.7
# 2006                          970.0                    46.6
# 11012                        1360.0                    -1.0
# 20000                         220.0                    56.5
# 35000                         340.0                    46.8
# 70000                        1100.0                    -3.5
# 120000                        540.0                   -34.2
#
#         fe_market_close_London_time  symbol
# 1                             365.0  EURUSD
# 5                             385.0  EURUSD
# 1000                         1040.0  EURUSD
# 2006                          310.0  EURUSD
# 11012                         700.0  EURUSD
# 20000                        1000.0  EURUSD
# 35000                        1120.0  EURUSD
# 70000                         440.0  EURUSD
# 120000                       1320.0  EURUSD

# %% [markdown]
# **Time**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_time/fe_time.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time  fe_time_month  fe_time_quarter  fe_time_semester  \
# 1      2023-01-03 00:05:00              1                1                 1
# 5      2023-01-03 00:25:00              1                1                 1
# 1000   2023-01-06 11:20:00              1                1                 1
# 2006   2023-01-11 23:10:00              1                1                 1
# 11012  2023-02-24 05:40:00              2                1                 1
# 20000  2023-04-10 10:40:00              4                2                 1
# 35000  2023-06-21 12:40:00              6                2                 1
# 70000  2023-12-08 01:20:00             12                4                 2
# 120000 2024-08-07 16:00:00              8                3                 2
#
#         fe_time_week  fe_time_day_of_week  fe_time_day_of_month  \
# 1                  1                    0                     2
# 5                  1                    0                     2
# 1000               1                    4                     6
# 2006               2                    2                    11
# 11012              8                    3                    23
# 20000             15                    0                    10
# 35000             25                    2                    21
# 70000             49                    3                     7
# 120000            32                    2                     7
#
#         fe_time_day_of_year  fe_time_month_start  fe_time_month_end  \
# 1                         2                    0                  0
# 5                         2                    0                  0
# 1000                      6                    0                  0
# 2006                     11                    0                  0
# 11012                    54                    0                  0
# 20000                   100                    0                  0
# 35000                   172                    0                  0
# 70000                   341                    0                  0
# 120000                  220                    0                  0
#
#         fe_time_quarter_start  fe_time_quarter_end  fe_time_year_start  \
# 1                           0                    0                   0
# 5                           0                    0                   0
# 1000                        0                    0                   0
# 2006                        0                    0                   0
# 11012                       0                    0                   0
# 20000                       0                    0                   0
# 35000                       0                    0                   0
# 70000                       0                    0                   0
# 120000                      0                    0                   0
#
#         fe_time_year_end  fe_time_hour  fe_time_minute  fe_time_isin_New_York  \
# 1                      0            17               5                      0
# 5                      0            17              25                      0
# 1000                   0             4              20                      0
# 2006                   0            16              10                      1
# 11012                  0            22              40                      0
# 20000                  0             3              40                      0
# 35000                  0             5              40                      0
# 70000                  0            18              20                      0
# 120000                 0             9               0                      1
#
#         fe_time_isin_Tokyo  fe_time_isin_Sydney  fe_time_isin_London  symbol
# 1                        0                    1                    0  EURUSD
# 5                        0                    1                    0  EURUSD
# 1000                     0                    0                    1  EURUSD
# 2006                     0                    1                    0  EURUSD
# 11012                    1                    1                    0  EURUSD
# 20000                    1                    0                    1  EURUSD
# 35000                    0                    0                    1  EURUSD
# 70000                    0                    1                    0  EURUSD
# 120000                   0                    0                    1  EURUSD

# %% [markdown]
# ### D) Window Features

# %%
history_fe_WIN_features(config_general)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
# INFO:test run:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
#   [test run][INFO]:---> symbol: EURUSD
# INFO:test run:---> symbol: EURUSD
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
# INFO:test run:--> history_fe_WIN_features run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_WIN/fe_WIN_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time  symbol  fe_WIN_min_W5_M5  fe_WIN_argmin_W5_M5  \
# 1      2023-01-03 00:05:00  EURUSD               NaN                  NaN
# 5      2023-01-03 00:25:00  EURUSD               0.2                 1.00
# 1000   2023-01-06 11:20:00  EURUSD               0.0                 0.00
# 2006   2023-01-11 23:10:00  EURUSD               1.3                 0.75
# 11012  2023-02-24 05:40:00  EURUSD               0.0                 0.00
# 20000  2023-04-10 10:40:00  EURUSD               2.2                 0.50
# 35000  2023-06-21 12:40:00  EURUSD               0.0                 0.00
# 70000  2023-12-08 01:20:00  EURUSD               0.0                 0.00
# 120000 2024-08-07 16:00:00  EURUSD               3.8                 1.00
#
#         fe_WIN_max_W5_M5  fe_WIN_argmax_W5_M5  fe_WIN_min_W10_M5  \
# 1                    NaN                  NaN                NaN
# 5                    0.1                 0.50                NaN
# 1000                11.7                 0.75                0.0
# 2006                 3.5                 1.00                1.3
# 11012                2.8                 1.00                4.6
# 20000                0.1                 1.00                4.0
# 35000                3.5                 0.75                5.9
# 70000                4.9                 1.00                0.0
# 120000               1.8                 0.25                5.6
#
#         fe_WIN_argmin_W10_M5  fe_WIN_max_W10_M5  fe_WIN_argmax_W10_M5  \
# 1                        NaN                NaN                   NaN
# 5                        NaN                NaN                   NaN
# 1000                  0.0000               17.6                0.8889
# 2006                  0.3333                3.5                0.4444
# 11012                 1.0000                2.8                0.4444
# 20000                 1.0000                0.6                0.5556
# 35000                 0.6667                3.5                0.3333
# 70000                 0.0000                4.9                0.4444
# 120000                0.7778                1.8                0.1111
#
#         fe_WIN_min_W48_M5  fe_WIN_argmin_W48_M5  fe_WIN_max_W48_M5  \
# 1                     NaN                   NaN                NaN
# 5                     NaN                   NaN                NaN
# 1000                  0.0                0.0000               21.2
# 2006                 14.6                0.9574                8.0
# 11012                 5.8                0.5319               11.5
# 20000                16.1                0.6596                0.6
# 35000                15.5                0.7447                5.2
# 70000                 0.1                0.5106               13.2
# 120000               10.1                0.7447                5.0
#
#         fe_WIN_argmax_W48_M5  fe_WIN_min_W288_M5  fe_WIN_argmin_W288_M5  \
# 1                        NaN                 NaN                    NaN
# 5                        NaN                 NaN                    NaN
# 1000                  0.2766                 0.0                 0.0000
# 2006                  0.3191                28.8                 0.5087
# 11012                 0.6809                23.5                 0.4390
# 20000                 0.1064                22.3                 0.8014
# 35000                 0.3404                29.3                 0.7909
# 70000                 0.9574                33.0                 0.7561
# 120000                0.3404                12.6                 0.3101
#
#         fe_WIN_max_W288_M5  fe_WIN_argmax_W288_M5  fe_WIN_min_W480_M5  \
# 1                      NaN                    NaN                 NaN
# 5                      NaN                    NaN                 NaN
# 1000                 120.7                 0.9930                 0.0
# 2006                  17.4                 0.2369                39.4
# 11012                 25.9                 0.8850                23.5
# 20000                 12.8                 0.8676                22.3
# 35000                 10.1                 0.8990                29.3
# 70000                 23.4                 0.2334                33.0
# 120000                13.6                 0.9233                15.9
#
#         fe_WIN_argmin_W480_M5  fe_WIN_max_W480_M5  fe_WIN_argmax_W480_M5
# 1                         NaN                 NaN                    NaN
# 5                         NaN                 NaN                    NaN
# 1000                   0.0000               122.9                 0.8121
# 2006                   0.7912                17.4                 0.1420
# 11012                  0.2630                54.1                 0.9248
# 20000                  0.4802                27.9                 0.9812
# 35000                  0.4739                19.6                 0.6451
# 70000                  0.4530                23.4                 0.1399
# 120000                 0.6451                42.6                 0.9040

# %% [markdown]
# ## Integrating All Features

# %%
history_columns_merge(config_general,general_mode=True)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
#   [test run][INFO]:--> start history_columns_merge fumc:
# INFO:test run:--> start history_columns_merge fumc:
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
#   [test run][INFO]:--> add fe_time.
# INFO:test run:--> add fe_time.
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
# INFO:test run: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
# INFO:test run:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | fe_WIN
# INFO:test run:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | fe_EMA
# INFO:test run:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | fe_market_close
# INFO:test run:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | fe_cndl
# INFO:test run:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | fe_ratio
# INFO:test run:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | fe_ATR
# INFO:test run:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | fe_RSI
# INFO:test run:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | fe_SMA
# INFO:test run:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | fe_RSTD
# INFO:test run:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
#   [test run][INFO]:--> (136836, 179)
# INFO:test run:--> (136836, 179)
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
# INFO:test run:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	90864
# ] / 136836
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
#   [test run][INFO]:--> trg_cols:0 | fe_cols:178
# INFO:test run:--> trg_cols:0 | fe_cols:178
# Mem. usage decreased to 79.77 Mb (51.9% reduction)
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> df final shape: (135349, 180) | dataset saved.
# INFO:test run:--> df final shape: (135349, 180) | dataset saved.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
#   [test run][INFO]:--> history_fe_time run successfully.
# INFO:test run:--> history_fe_time run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/dataset/dataset.parqu
# 35000                                   0.00104
# 70000                                   0.00043
# 120000                                  0.00079
#
#         fe_cndl_shift_EURUSD_M30_HIGH_to_CLOSE_-1  \
# 1                                         0.00036
# 5                                         0.00036
# 1000                                      0.00007
# 2006                                      0.00095
# 11012                                     0.00053
# 20000                                     0.00097
# 35000                                     0.00004
# 70000                                     0.00013
# 120000                                    0.00066
#
#         fe_cndl_shift_EURUSD_M30_HIGH_to_OPEN_-1  \
# 1                                        0.00042
# 5                                        0.00042
# 1000                                     0.00019
# 2006                                     0.00028
# 11012                                    0.00002
# 20000                                    0.00027
# 35000                                    0.00064
# 70000                                    0.00024
# 120000                                   0.00009
#
#         fe_cndl_shift_EURUSD_M30_OPEN_to_LOW_-1  \
# 1                                       0.00022
# 5                                       0.00022
# 1000                                    0.00074
# 2006                                    0.00078
# 11012                                   0.00087
# 20000                                   0.00077
# 35000                                   0.00040
# 70000                                   0.00019
# 120000                                  0.00070
#
#         fe_cndl_shift_EURUSD_M30_CLOSE_to_LOW_-1  \
# 1                                        0.00028
# 5                                        0.00028
# 1000                                     0.00086
# 2006                                     0.00011
# 11012                                    0.00036
# 20000                                    0.00007
# 35000                                    0.00100
# 70000                                    0.00030
# 120000                                   0.00013
#
#         fe_cndl_shift_EURUSD_M60_CLOSE_to_OPEN_-1  \
# 1                                         0.00087
# 5                                         0.00087
# 1000                                     -0.00002
# 2006                                     -0.00102
# 11012                                     0.00121
# 20000                                     0.00012
# 35000                                    -0.00129
# 70000                                     0.00127
# 120000                                   -0.00123
#
#         fe_cndl_shift_EURUSD_M60_HIGH_to_LOW_-1  \
# 1                                       0.00137
# 5                                       0.00137
# 1000                                    0.00126
# 2006                                    0.00121
# 11012                                   0.00142
# 20000                                   0.00127
# 35000                                   0.00186
# 70000                                   0.00141
# 120000                                  0.00149
#
#         fe_cndl_shift_EURUSD_M60_HIGH_to_CLOSE_-1  \
# 1                                         0.00036
# 5                                         0.00036
# 1000                                      0.00040
# 2006                                      0.00110
# 11012                                     0.00020
# 20000                                     0.00033
# 35000                                     0.00169
# 70000                                     0.00013
# 120000                                    0.00129
#
#         fe_cndl_shift_EURUSD_M60_HIGH_to_OPEN_-1  \
# 1                                        0.00123
# 5                                        0.00123
# 1000                                     0.00038
# 2006                                     0.00008
# 11012                                    0.00141
# 20000                                    0.00045
# 35000                                    0.00040
# 70000                                    0.00140
# 120000                                   0.00006
#
#         fe_cndl_shift_EURUSD_M60_OPEN_to_LOW_-1  \
# 1                                       0.00014
# 5                                       0.00014
# 1000                                    0.00088
# 2006                                    0.00113
# 11012                                   0.00001
# 20000                                   0.00082
# 35000                                   0.00146
# 70000                                   0.00001
# 120000                                  0.00143
#
#         fe_cndl_shift_EURUSD_M60_CLOSE_to_LOW_-1  \
# 1                                        0.00101
# 5                                        0.00101
# 1000                                     0.00086
# 2006                                     0.00011
# 11012                                    0.00122
# 20000                                    0.00094
# 35000                                    0.00017
# 70000                                    0.00128
# 120000                                   0.00020
#
#         fe_cndl_shift_EURUSD_M240_CLOSE_to_OPEN_-1  \
# 1                                          0.00067
# 120000                                    0.00173
#
#         fe_cndl_shift_EURUSD_M1440_CLOSE_to_LOW_-1  fe_WIN_min_EURUSD_W5_M5  \
# 1                                          0.00912                      0.3
# 5                                          0.00912                      3.7
# 1000                                       0.01219                      3.9
# 2006                                       0.00274                      7.1
# 11012                                      0.00193                      2.3
# 20000                                      0.00200                      0.2
# 35000                                      0.00584                      8.7
# 70000                                      0.01207                      0.5
# 120000                                     0.00789                      1.9
#
#         fe_WIN_argmin_EURUSD_W5_M5  fe_WIN_max_EURUSD_W5_M5  \
# 1                             0.75                      0.7
# 5                             1.00                      1.6
# 1000                          0.50                      0.9
# 2006                          0.50                      0.0
# 11012                         0.75                      3.5
# 20000                         0.25                      1.7
# 35000                         1.00                      0.9
# 70000                         0.50                      1.8
# 120000                        0.50                      0.0
#
#         fe_WIN_argmax_EURUSD_W5_M5  fe_WIN_min_EURUSD_W10_M5  \
# 1                             1.00                       7.5
# 5                             0.25                       4.0
# 1000                          0.25                       5.3
# 2006                          0.00                       7.1
# 11012                         0.25                       2.3
# 20000                         1.00                       0.2
# 35000                         0.25                      13.8
# 70000                         1.00                       0.5
# 120000                        0.00                       1.9
#
#         fe_WIN_argmin_EURUSD_W10_M5  fe_WIN_max_EURUSD_W10_M5  \
# 1                            1.0000                       1.7
# 5                            0.7778                       1.6
# 1000                         0.6667                       0.9
# 2006                         0.2222                       0.3
# 11012                        0.3333                       3.7
# 20000                        0.1111                       9.2
# 35000                        0.5556                       0.9
# 70000                        0.2222                       1.8
# 120000                       0.2222                       1.8
#
#         fe_WIN_argmax_EURUSD_W10_M5  fe_WIN_min_EURUSD_W48_M5  \
# 1                            0.5556                 13.300000
# 5                            0.1111                 17.000000
# 1000                         0.1111                  5.300000
# 2006                         0.7778                  7.100000
# 11012                        1.0000                 12.600000
# 20000                        1.0000                 10.000000
# 35000                        0.1111                 13.800000
# 70000                        0.4444                 16.799999
# 120000                       1.0000                  1.900000
#
#         fe_WIN_argmin_EURUSD_W48_M5  fe_WIN_max_EURUSD_W48_M5  \
# 1                            0.3404                  1.700000
# 5                            0.4255                  1.600000
# 1000                         0.1277                 38.299999
# 2006                         0.0426                  3.700000
# 11012                        1.0000                  3.700000
# 20000                        0.6809                 20.700001
# 35000                        0.1064                 23.299999
# 70000                        0.6383                  1.800000
# 120000                       0.0426                 28.000000
#
#         fe_WIN_argmax_EURUSD_W48_M5  fe_WIN_min_EURUSD_W288_M5  \
# 1                            0.7447                  72.699997
# 5                            0.0213                  76.400002
# 1000                         0.7872                  53.700001
# 2006                         0.2766                  26.400000
# 11012                        0.1915                  40.200001
# 20000                        0.9787                  12.100000
# 35000                        0.7872                  13.800000
# 70000                        0.0851                 114.599998
# 120000                       0.5957                  48.200001
#
#         fe_WIN_argmin_EURUSD_W288_M5  fe_WIN_max_EURUSD_W288_M5  \
# 1                             0.6655                  22.700001
# 5                             0.6794                  19.000000
# 1000                          0.9373                  53.900002
# 2006                          0.8780                  88.300003
# 11012                         0.5645                  22.799999
# 20000                         0.4355                  84.800003
# 35000                         0.0174                  37.799999
# 70000                         0.8084                  10.700000
# 120000                        1.0000                  28.000000
#
#         fe_WIN_argmax_EURUSD_W288_M5  fe_WIN_min_EURUSD_W480_M5  \
# 1                             0.3833                 247.800003
# 5                             0.3972                 251.500000
# 1000                          0.5401                  66.599998
# 2006                          0.4495                  26.400000
# 11012                         0.9930                  40.200001
# 20000                         0.9756                  12.100000
# 35000                         1.0000                  35.200001
# 70000                         0.4042                 217.000000
# 120000                        0.0976                 102.400002
#
#         fe_WIN_argmin_EURUSD_W480_M5  fe_WIN_max_EURUSD_W480_M5  \
# 1                             0.9374                  22.700001
# 5                             0.9457                  19.000000
# 1000                          0.7077                  53.900002
# 2006                          0.5261                  88.300003
# 11012                         0.3382                  59.200001
# 20000                         0.2610                  99.599998
# 35000                         0.9207                  37.799999
# 70000                         0.9979                  10.700000
# 120000                        0.7996                  28.000000
#
#         fe_WIN_argmax_EURUSD_W480_M5  fe_EMA_EURUSD_M5_CLOSE_W7_cndl_M5_norm  \
# 1                             0.2296                               -0.618143
# 5                             0.2380                               -1.326444
# 1000                          0.3236                               -1.251912
# 2006                          0.2693                               -2.811738
# 11012                         0.9645                                0.283397
# 20000                         0.7432                                2.055818
# 35000                         0.5992                               -4.167153
# 70000                         0.2422                               -0.004130
# 120000                        0.0585                               -0.173640
#
#         fe_EMA_EURUSD_M5_CLOSE_W60_cndl_M5_norm  \
# 1                                     -3.371779
# 5                                     -6.217613
# 1000                                  13.226524
# 2006                                   0.298323
# 11012                                 -5.725298
# 20000                                  5.586311
# 35000                                  4.001359
# 70000                                 -5.072363
# 120000                                 5.607835
#
#         fe_EMA_EURUSD_M5_CLOSE_W336_cndl_M5_norm  \
# 1                                     -38.265881
# 5                                     -40.984634
# 1000                                   10.494857
# 2006                                   14.288562
# 11012                                  -4.742026
# 20000                                  22.055304
# 35000                                   8.296917
# 70000                                 -50.723312
# 120000                                -20.775017
#
#         fe_EMA_EURUSD_M5_CLOSE_W1440_cndl_M5_norm  \
# 1                                     -105.891899
# 5                                     -108.899162
# 1000                                   -59.815380
# 2006                                     5.802020
# 11012                                   -1.879111
# 20000                                    4.012626
# 35000                                   -7.098099
# 70000                                 -142.747742
# 120000                                 -69.052254
#
#         fe_market_close_EURUSD_New_York  fe_market_close_EURUSD_New_York_time  \
# 1                              6.500000                                 245.0
# 5                             10.200000                                 265.0
# 1000                         -39.500000                                 920.0
# 2006                           0.800000                                 190.0
# 11012                         21.900000                                 580.0
# 20000                        -17.600000                                 880.0
# 35000                        -22.799999                                1000.0
# 70000                          3.500000                                 320.0
# 120000                        25.700001                                1200.0
#
#         fe_market_close_EURUSD_Tokyo  fe_market_close_EURUSD_Tokyo_time  \
# 1                          45.700001                             1025.0
# 5                          49.400002                             1045.0
# 1000                      -43.000000                              260.0
# 2006                      -48.700001                              970.0
# 11012                     -20.700001                             1360.0
# 20000                     -17.299999                              220.0
# 35000                     -14.800000                              340.0
# 70000                      93.699997                             1100.0
# 120000                     12.600000                              540.0
#
#         fe_market_close_EURUSD_Sydney  fe_market_close_EURUSD_Sydney_time  \
# 1                           59.400002                              1265.0
# 5                           63.099998                              1285.0
# 1000                       -27.700001                               500.0
# 2006                        20.100000                              1210.0
# 11012                        9.100000                               160.0
# 20000                       -1.600000                               460.0
# 35000                      -13.100000                               580.0
# 70000                       96.099998                              1340.0
# 120000                      28.299999                               780.0
#
#         fe_market_close_EURUSD_London  fe_market_close_EURUSD_London_time  \
# 1                           -4.200000                               605.0
# 5                           -0.500000                               625.0
# 1000                         5.400000                              1280.0
# 2006                       -38.700001                               550.0
# 11012                        9.000000                               940.0
# 20000                      -31.500000                              1240.0
# 35000                      -11.100000                              1360.0
# 70000                        2.000000                               680.0
# 120000                     -17.200001                               120.0
#
#         fe_cndl_EURUSD_M5_CLOSE_to_OPEN  fe_cndl_EURUSD_M5_HIGH_to_LOW  \
# 1                                  -0.2                            4.0
# 5                                  -1.5                            2.8
# 1000                               -1.2                            6.5
# 2006                                5.2                            6.4
# 11012                              -3.4                            4.5
# 20000                               0.2                            3.1
# 35000                              -0.9                            4.7
# 70000                              -0.3                            1.4
# 120000                              0.6                            1.8
#
#         fe_cndl_EURUSD_M5_HIGH_to_CLOSE  fe_cndl_EURUSD_M5_HIGH_to_OPEN  \
# 1                                   0.5                             0.3
# 5                                   2.6                             1.1
# 1000                                5.1                             3.9
# 2006                                0.9                             6.1
# 11012                               3.8                             0.4
# 20000                               2.0                             2.2
# 35000                               3.9                             3.0
# 70000                               1.0                             0.7
# 120000                              1.0                             1.6
#
#         fe_cndl_EURUSD_M5_OPEN_to_LOW  fe_cndl_EURUSD_M5_CLOSE_to_LOW  \
# 1                                 3.7                             3.5
# 5                                 1.7                             0.2
# 1000                              2.6                             1.4
# 2006                              0.3                             5.5
# 11012                             4.1                             0.7
# 20000                             0.9                             1.1
# 35000                             1.7                             0.8
# 70000                             0.7                             0.4
# 120000                            0.2                             0.8
#
#         fe_cndl_EURUSD_M15_CLOSE_to_OPEN  fe_cndl_EURUSD_M15_HIGH_to_LOW  \
# 1                                   -0.2                             4.0
# 5                                   -0.7                             3.2
# 1000                                -1.2                             6.5
# 2006                                 7.1                             9.0
# 11012                                1.6                             7.3
# 20000                                0.0                             4.2
# 35000                                4.1                            12.3
# 70000                               -0.3                             1.4
# 120000                               0.4                             3.9
#
#         fe_cndl_EURUSD_M15_HIGH_to_CLOSE  fe_cndl_EURUSD_M15_HIGH_to_OPEN  \
# 1                                    0.5                              0.3
# 5                                    2.9                              2.2
# 1000                                 5.1                              3.9
# 2006                                 0.9                              8.0
# 11012                                5.2                              6.8
# 20000                                2.0                              2.0
# 35000                                6.6                             10.7
# 70000                                1.0                              0.7
# 120000                               1.0                              1.4
#
#         fe_cndl_EURUSD_M15_OPEN_to_LOW  fe_cndl_EURUSD_M15_CLOSE_to_LOW  \
# 1                                  3.7                              3.5
# 5                                  1.0                              0.3
# 1000                               2.6                              1.4
# 2006                               1.0                              8.1
# 11012                              0.5                              2.1
# 20000                              2.2                              2.2
# 35000                              1.6                              5.7
# 70000                              0.7                              0.4
# 120000                             2.5                              2.9
#
#         fe_cndl_EURUSD_M30_CLOSE_to_OPEN  fe_cndl_EURUSD_M30_HIGH_to_LOW  \
# 1                                   -0.2                             4.0
# 5                                    3.5                            10.1
# 1000                                 0.2                             9.1
# 2006                                 7.1                             9.0
# 11012                                1.6                             7.3
# 20000                                0.0                             4.2
# 35000                                4.1                            12.3
# 70000                               -1.7                             2.9
# 120000                               0.8                             4.8
#
#         fe_cndl_EURUSD_M30_HIGH_to_CLOSE  fe_cndl_EURUSD_M30_HIGH_to_OPEN  \
# 1                                    0.5                              0.3
# 5                                    2.9                              6.4
# 1000                                 5.1                              5.3
# 2006                                 0.9                              8.0
# 11012                                5.2                              6.8
# 20000                                2.0                              2.0
# 35000                                6.6                             10.7
# 70000                                2.2                              0.5
# 120000                               1.9                              2.7
#
#         fe_cndl_EURUSD_M30_OPEN_to_LOW  fe_cndl_EURUSD_M30_CLOSE_to_LOW  \
# 1                                  3.7                              3.5
# 5                                  3.7                              7.2
# 1000                               3.8                              4.0
# 2006                               1.0                              8.1
# 11012                              0.5                              2.1
# 20000                              2.2                              2.2
# 35000                              1.6                              5.7
# 70000                              2.4                              0.7
# 120000                             2.1                              2.9
#
#         fe_cndl_EURUSD_M60_CLOSE_to_OPEN  fe_cndl_EURUSD_M60_HIGH_to_LOW  \
# 1                                   -0.2                        4.000000
# 5                                    3.5                       10.100000
# 1000                                 0.2                        9.100000
# 2006                                 7.1                        9.000000
# 11012                               -3.4                       10.500000
# 20000                               -7.0                       11.900000
# 35000                               10.1                       20.700001
# 70000                               -1.7                        2.900000
# 120000                              -4.9                        8.700000
#
#         fe_cndl_EURUSD_M60_HIGH_to_CLOSE  fe_cndl_EURUSD_M60_HIGH_to_OPEN  \
# 1                                    0.5                         0.300000
# 5                                    2.9                         6.400000
# 1000                                 5.1                         5.300000
# 2006                                 0.9                         8.000000
# 11012                                5.2                         1.800000
# 20000                                9.7                         2.700000
# 35000                                6.6                        16.700001
# 70000                                2.2                         0.500000
# 120000                               5.8                         0.900000
#
#         fe_cndl_EURUSD_M60_OPEN_to_LOW  fe_cndl_EURUSD_M60_CLOSE_to_LOW  \
# 1                                  3.7                              3.5
# 5                                  3.7                              7.2
# 1000                               3.8                              4.0
# 2006                               1.0                              8.1
# 11012                              8.7                              5.3
# 20000                              9.2                              2.2
# 35000                              4.0                             14.1
# 70000                              2.4                              0.7
# 120000                             7.8                              2.9
#
#         fe_cndl_EURUSD_M240_CLOSE_to_OPEN  fe_cndl_EURUSD_M240_HIGH_to_LOW  \
# 1                                    -0.2                         4.000000
# 5                                     3.5                        10.100000
# 1000                                -30.1                        48.500000
# 2006                                  1.5                        12.100000
# 11012                                 8.6                        14.200000
# 20000                                10.2                        20.500000
# 35000                                10.1                        20.700001
# 70000                                10.9                        14.100000
# 120000                                1.5                        31.900000
#
#         fe_cndl_EURUSD_M240_HIGH_to_CLOSE  fe_cndl_EURUSD_M240_HIGH_to_OPEN  \
# 1                                     0.5                          0.300000
# 5                                     2.9                          6.400000
# 1000                                 39.5                          9.400000
# 2006                                  3.9                          5.400000
# 11012                                 5.5                         14.100000
# 20000                                10.3                         20.500000
# 35000                                 6.6                         16.700001
# 70000                                 3.1                         14.000000
# 120000                               29.0                         30.500000
#
#         fe_cndl_EURUSD_M240_OPEN_to_LOW  fe_cndl_EURUSD_M240_CLOSE_to_LOW  \
# 1                              3.700000                               3.5
# 5                              3.700000                               7.2
# 1000                          39.099998                               9.0
# 2006                           6.700000                               8.2
# 11012                          0.100000                               8.7
# 20000                          0.000000                              10.2
# 35000                          4.000000                              14.1
# 70000                          0.100000                              11.0
# 120000                         1.400000                               2.9
#
#         fe_cndl_EURUSD_M1440_CLOSE_to_OPEN  fe_cndl_EURUSD_M1440_HIGH_to_LOW  \
# 1                                 6.500000                         19.100000
# 5                                10.200000                         21.900000
# 1000                            -35.500000                         64.800003
# 2006                              1.500000                         12.100000
# 11012                            21.900000                         28.500000
# 20000                           -14.200000                         38.200001
# 35000                           -22.500000                         39.099998
# 70000                             3.900000                         21.799999
# 120000                           25.700001                         64.300003
#
#         fe_cndl_EURUSD_M1440_HIGH_to_CLOSE  fe_cndl_EURUSD_M1440_HIGH_to_OPEN  \
# 1                                 3.800000                          10.300000
# 5                                 2.900000                          13.100000
# 1000                             55.799999                          20.299999
# 2006                              3.900000                           5.400000
# 11012                             5.500000                          27.400000
# 20000                            25.100000                          10.900000
# 35000                            25.000000                           2.500000
# 70000                             3.100000                           7.000000
# 120000                           29.000000                          54.700001
#
# ...
# 20000                                         False
# 35000                                         False
# 70000                                         False
# 120000                                        False
#
#         fe_RSI_EURUSD_M5_CLOSE_W7_cndl_M5  \
# 1                               67.008369
# 5                               69.474144
# 1000                            53.523361
# 2006                            56.601704
# 11012                           50.922421
# 20000                           29.227274
# 35000                           64.174454
# 70000                           59.253334
# 120000                          43.279655
#
#         fe_RSI_EURUSD_M5_CLOSE_W7_gte_70_cndl_M5  \
# 1                                          False
# 5                                          False
# 1000                                       False
# 2006                                       False
# 11012                                      False
# 20000                                      False
# 35000                                      False
# 70000                                      False
# 120000                                     False
#
#         fe_RSI_EURUSD_M5_CLOSE_W7_lte_30_cndl_M5  \
# 1                                          False
# 5                                          False
# 1000                                       False
# 2006                                       False
# 11012                                      False
# 20000                                       True
# 35000                                      False
# 70000                                      False
# 120000                                     False
#
#         fe_RSI_EURUSD_M60_CLOSE_W30_cndl_M60  \
# 1                                  63.320560
# 5                                  63.320560
# 1000                               52.922226
# 2006                               46.357422
# 11012                              51.222782
# 20000                              45.953514
# 35000                              46.936672
# 70000                              70.201591
# 120000                             64.269325
#
#         fe_RSI_EURUSD_M60_CLOSE_W30_gte_70_cndl_M60  \
# 1                                             False
# 5                                             False
# 1000                                          False
# 2006                                          False
# 11012                                         False
# 20000                                         False
# 35000                                         False
# 70000                                          True
# 120000                                        False
#
#         fe_RSI_EURUSD_M60_CLOSE_W30_lte_30_cndl_M60  \
# 1                                             False
# 5                                             False
# 1000                                          False
# 2006                                          False
# 11012                                         False
# 20000                                         False
# 35000                                         False
# 70000                                         False
# 120000                                        False
#
#         fe_RSI_EURUSD_M240_CLOSE_W7_cndl_M240  \
# 1                                   75.481216
# 5                                   75.481216
# 1000                                74.815002
# 2006                                43.463978
# 11012                               48.155659
# 20000                               35.754040
# 35000                               42.534302
# 70000                               80.886047
# 120000                              85.610374
#
#         fe_RSI_EURUSD_M240_CLOSE_W7_gte_70_cndl_M240  \
# 1                                               True
# 5                                               True
# 1000                                            True
# 2006                                           False
# 11012                                          False
# 20000                                          False
# 35000                                          False
# 70000                                           True
# 120000                                          True
#
#         fe_RSI_EURUSD_M240_CLOSE_W7_lte_30_cndl_M240  \
# 1                                              False
# 5                                              False
# 1000                                           False
# 2006                                           False
# 11012                                          False
# 20000                                          False
# 35000                                          False
# 70000                                          False
# 120000                                         False
#
#         fe_RSI_EURUSD_M240_CLOSE_W30_cndl_M240  \
# 1                                    62.347309
# 5                                    62.347309
# 1000                                 67.966003
# 2006                                 52.709877
# 11012                                47.784069
# 20000                                52.447880
# 35000                                52.815094
# 70000                                66.232155
# 120000                               66.118973
#
#         fe_RSI_EURUSD_M240_CLOSE_W30_gte_70_cndl_M240  \
# 1                                               False
# 5                                               False
# 1000                                            False
# 2006                                            False
# 11012                                           False
# 20000                                           False
# 35000                                           False
# 70000                                           False
# 120000                                          False
#
#         fe_RSI_EURUSD_M240_CLOSE_W30_lte_30_cndl_M240  \
# 1                                               False
# 5                                               False
# 1000                                            False
# 2006                                            False
# 11012                                           False
# 20000                                           False
# 35000                                           False
# 70000                                           False
# 120000                                          False
#
#         fe_RSI_EURUSD_M5_CLOSE_W30_cndl_M5  \
# 1                                53.667595
# 5                                56.658966
# 1000                             41.394287
# 2006                             49.807106
# 11012                            56.943623
# 20000                            44.974308
# 35000                            47.191574
# 70000                            56.823807
# 120000                           45.390705
#
#         fe_RSI_EURUSD_M5_CLOSE_W30_gte_70_cndl_M5  \
# 1                                           False
# 5                                           False
# 1000                                        False
# 2006                                        False
# 11012                                       False
# 20000                                       False
# 35000                                       False
# 70000                                       False
# 120000                                      False
#
#         fe_RSI_EURUSD_M5_CLOSE_W30_lte_30_cndl_M5  \
# 1                                           False
# 5                                           False
# 1000                                        False
# 2006                                        False
# 11012                                       False
# 20000                                       False
# 35000                                       False
# 70000                                       False
# 120000                                      False
#
#         fe_RSI_EURUSD_M240_CLOSE_W14_cndl_M240  \
# 1                                    68.669296
# 5                                    68.669296
# 1000                                 73.448418
# 2006                                 48.118778
# 11012                                49.192360
# 20000                                46.425034
# 35000                                48.910027
# 70000                                76.554535
# 120000                               76.437233
#
#         fe_RSI_EURUSD_M240_CLOSE_W14_gte_70_cndl_M240  \
# 1                                               False
# 5                                               False
# 1000                                             True
# 2006                                            False
# 11012                                           False
# 20000                                           False
# 35000                                           False
# 70000                                            True
# 120000                                           True
#
#         fe_RSI_EURUSD_M240_CLOSE_W14_lte_30_cndl_M240  \
# 1                                               False
# 5                                               False
# 1000                                            False
# 2006                                            False
# 11012                                           False
# 20000                                           False
# 35000                                           False
# 70000                                           False
# 120000                                          False
#
#         fe_RSI_EURUSD_M60_CLOSE_W7_cndl_M60  \
# 1                                 59.413433
# 5                                 59.413433
# 1000                              29.692562
# 2006                              36.619518
# 11012                             68.119522
# 20000                             47.109966
# 35000                             30.150309
# 70000                             68.729713
# 120000                            52.586559
#
#         fe_RSI_EURUSD_M60_CLOSE_W7_gte_70_cndl_M60  \
# 1                                            False
# 5                                            False
# 1000                                         False
# 2006                                         False
# 11012                                        False
# 20000                                        False
# 35000                                        False
# 70000                                        False
# 120000                                       False
#
#         fe_RSI_EURUSD_M60_CLOSE_W7_lte_30_cndl_M60  \
# 1                                            False
# 5                                            False
# 1000                                          True
# 2006                                         False
# 11012                                        False
# 20000                                        False
# 35000                                        False
# 70000                                        False
# 120000                                       False
#
#         fe_RSI_EURUSD_M5_CLOSE_W14_cndl_M5  \
# 1                                60.715630
# 5                                64.806664
# 1000                             43.942078
# 2006                             52.712555
# 11012                            55.000954
# 20000                            40.670143
# 35000                            52.538689
# 70000                            61.322426
# 120000                           40.680882
#
#         fe_RSI_EURUSD_M5_CLOSE_W14_gte_70_cndl_M5  \
# 1                                           False
# 5                                           False
# 1000                                        False
# 2006                                        False
# 11012                                       False
# 20000                                       False
# 35000                                       False
# 70000                                       False
# 120000                                      False
#
#         fe_RSI_EURUSD_M5_CLOSE_W14_lte_30_cndl_M5  \
# 1                                           False
# 5                                           False
# 1000                                        False
# 2006                                        False
# 11012                                       False
# 20000                                       False
# 35000                                       False
# 70000                                       False
# 120000                                      False
#
#         fe_SMA_EURUSD_M5_CLOSE_W480_cndl_M5_norm  \
# 1                                     -71.275414
# 5                                     -73.074997
# 1000                                   -5.105000
# 2006                                   14.877084
# 11012                                   9.376041
# 20000                                  43.592499
# 35000                                   6.082500
# 70000                                 -88.363747
# 120000                                -40.756668
#
#         fe_SMA_EURUSD_M5_CLOSE_W240_cndl_M5_norm  \
# 1                                     -19.352501
# 5                                     -22.094166
# 1000                                   31.065416
# 2006                                   21.451666
# 11012                                 -15.025416
# 20000                                   9.904583
# 35000                                  14.552500
# 70000                                 -32.122501
# 120000                                -11.080417
#
#         fe_SMA_EURUSD_M5_CLOSE_W720_cndl_M5_norm  \
# 1                                    -117.668198
# 5                                    -120.356392
# 1000                                  -25.360971
# 2006                                   19.096390
# 11012                                   5.271945
# 20000                                  43.924026
# 35000                                  -6.404305
# 70000                                -127.592636
# 120000                                -57.724583
#
#         fe_RSTD_EURUSD_M240_CLOSE_W14_cndl_M240  \
# 1                                     28.851866
# 5                                     28.851866
# 1000                                  17.349237
# 2006                                  33.624756
# 11012                                 20.490879
# 20000                                 21.546791
# 35000                                 13.515774
# 70000                                 27.799011
# 120000                                11.737267
#
#         fe_RSTD_EURUSD_M240_CLOSE_W7_cndl_M240  \
# 1                                    22.196075
# 5                                    22.196075
# 1000                                 23.693676
# 2006                                 42.221737
# 11012                                17.424744
# 20000                                22.011786
# 35000                                13.938065
# 70000                                24.693329
# 120000                               13.192917
#
#         fe_RSTD_EURUSD_M240_CLOSE_W30_cndl_M240   symbol
# 1                                     33.800598  dataset
# 5                                     33.800598  dataset
# 1000                                  22.990681  dataset
# 2006                                  29.125542  dataset
# 11012                                 19.887671  dataset
# 20000                                 21.233007  dataset
# 35000                                 21.077250  dataset
# 70000                                 21.849094  dataset
# 120000                                11.449204  dataset

# %% [markdown]
# # 1. Single Experiment (Manual)

# %%
print('MANUAL_EXP:',MANUAL_EXP)
man_params = {'RF':None, 'XGB':None}
# Out:
# MANUAL_EXP: True

# %%
man_params['RF'] = {
    'model_name' : 'RF',

    'target_symbol' : 'EURUSD',
    'trade_mode': 'long' ,   #"long" , "short"
    'trg_look_ahead' : 300,
    'trg_take_profit' : 40,
    'trg_stop_loss' : 15,

    'strg_look_ahead' : 300,
    'strg_take_profit' : 40,
    'strg_stop_loss' : 15,


    'n_rand_features': None,
    'save_model_mode' : None, # None, 'sample_train_size', 'last_train_size', 'all_data',
    'n_splits' : 18,
    'max_train_size' : 500*288,
    'test_size' : 30*288,
    'train_test_gap':30*288,

    'parameters':{
        'n_estimators' : 100,
        'max_depth': 5,
        'max_features' : 64,
        'max_samples' : 0.5,
        'class_weight': {0:1,1:1}, # 'balanced'
        'random_state': 42,
        'n_jobs': -1
        }
              }

# %%
man_params['XGB'] = {
    'model_name' : 'XGB',

    'target_symbol' : 'EURUSD',
    'trade_mode': 'long' ,   #"long" , "short"
    'trg_look_ahead' : 400,
    'trg_take_profit' : 30,
    'trg_stop_loss' : 7,

    'strg_look_ahead' : 300,
    'strg_take_profit' : 30,
    'strg_stop_loss' : 20,

    'n_rand_features': None,
    'save_model_mode' : None, # None, 'sample_train_size', 'last_train_size', 'all_data',
    'n_splits' : 3,
    'max_train_size' : 900*288,
    'test_size' : 30*288,
    'train_test_gap':30*288,

    "parameters": {
        'tree_method':'hist',#  None,hist
        'device' : 'cpu',#  None,'cuda'
        "objective": "binary:logistic",
        "max_depth": 7,
        "learning_rate": 0.15,
        "n_estimators": 50,
    #         "early_stopping_rounds" :{"distribution": "int_uniform", "min": 5, "max": 150},
        "early_stopping_rounds" :None,

#         "gamma": 7, #? float
#         "min_child_weight": 1,
        # Used to control over-fitting.
#         "max_delta_step": 2, #?float
        "subsample": 0.5,
        "colsample_bytree": 0.8,
        "reg_lambda": 0.01,
        "reg_alpha": 0.01,
        "scale_pos_weight" :1,
        'random_state': 0,
        },
}

# %%
if MANUAL_EXP:
    exp_obj, exp_metadata, artifact_name = main(
        manual = True,
        man_params = man_params[model_type],
        dataset_path = "/content/ML-Algotrading-Project/dataset/data/dataset/dataset.parquet",
        C5M_data_path = "/content/ML-Algotrading-Project/dataset/data/stage_one_data/",
    )
# Out:
# Final Parameters of the Model: {'tree_method': 'hist', 'device': 'cpu', 'objective': 'binary:logistic', 'max_depth': 7, 'learning_rate': 0.15, 'n_estimators': 50, 'early_stopping_rounds': None, 'subsample': 0.5, 'colsample_bytree': 0.8, 'reg_lambda': 0.01, 'reg_alpha': 0.01, 'scale_pos_weight': 1, 'random_state': 0}
# Len all columns in dataframe is 180
# Len read columns is 180
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M400_TP30_SL7 has been generated in 4.14 seconds
# df shape:  (135269, 181)
# ==============================
# --> df final shape: (135269, 180)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-10-28 20:15:00
# --> number of unique days: 135269
# ==============================
# Percentage of the True Class: 7.0
# Fold 0:
# --> fold train size: (74789, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall    TP   FP     TN    FN  \
# 0   train  0      0.87       0.97    0.78  4755  156  68554  1324
# 1   valid  0      0.02       0.03    0.02     8  261   7967   404
# 2    test  0      0.01       0.03    0.01     4  151   7964   521
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-01-08 20:15:00            8.2             NaN
# 1 2024-02-19 20:20:00 2024-04-01 20:15:00            8.2         -166.12
# 2 2024-04-01 20:20:00 2024-05-13 20:15:00            8.2          -79.68
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1 -153.34            11              77
# 2 -123.90             8              44
# Fold 1:
# --> fold train size: (92069, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall    TP   FP     TN    FN  \
# 3   train  1      0.83       0.97    0.72  5065  156  84910  1938
# 4   valid  1      0.00       0.00    0.00     0    1   8110   529
# 5    test  1      0.02       0.14    0.01     5   31   8149   455
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-04-01 20:15:00            8.6             NaN
# 4 2024-05-13 20:20:00 2024-06-24 20:15:00            8.6            -2.2
# 5 2024-06-24 20:20:00 2024-08-05 20:15:00            8.6            -5.9
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4    0.00             1               1
# 5  -14.06             8               7
# Fold 2:
# --> fold train size: (109349, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall    TP   FP      TN    FN  \
# 6   train  2      0.80       0.97    0.68  5439  165  101127  2618
# 7   valid  2      0.01       0.04    0.00     2   47    8058   533
# 8    test  2      0.05       0.22    0.03    11   40    8182   407
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-10 03:55:00 2024-06-24 20:15:00            7.3             NaN
# 7 2024-08-05 20:20:00 2024-09-16 20:15:00            7.3          -24.71
# 8 2024-09-16 20:20:00 2024-10-28 20:15:00            7.3          -31.72
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7  -34.29             7              21
# 8  -43.46             6              17
# CV loop ends
# {'profit_percent_val': -193.03, 'max_dd_val': -157.45, 'profit_percent_test': -117.3, 'max_dd_test': -130.96}
# object stored as pickle: XGB_long_EURUSD_M400_TP30_SL7_prof-117.30_max_dd-130.96_median_sig45.00_date2024-10-29_14:59.pkl
# object pickle stored zipped: XGB_long_EURUSD_M400_TP30_SL7_prof-117.30_max_dd-130.96_median_sig45.00_date2024-10-29_14:59.pkl

# %%
imp_fe = list(exp_obj.feature_importance[exp_obj.feature_importance.cv<.5].feature_name)
exp_obj.feature_importance[exp_obj.feature_importance.cv<.5].feature_name
# Out:
# 84              fe_market_close_EURUSD_Sydney_time
# 13                                    fe_time_hour
# 86              fe_market_close_EURUSD_London_time
# 51     fe_cndl_shift_EURUSD_M1440_HIGH_to_CLOSE_-1
# 175        fe_RSTD_EURUSD_M240_CLOSE_W14_cndl_M240
#                           ...
# 87                 fe_cndl_EURUSD_M5_CLOSE_to_OPEN
# 21        fe_cndl_shift_EURUSD_M5_HIGH_to_CLOSE_-1
# 98                 fe_cndl_EURUSD_M15_CLOSE_to_LOW
# 24         fe_cndl_shift_EURUSD_M5_CLOSE_to_LOW_-1
# 19        fe_cndl_shift_EURUSD_M5_CLOSE_to_OPEN_-1
# Name: feature_name, Length: 142, dtype: object

# %%
def plot_feature_importances_scatter(importance_df, top_n=10, figsize=(8, 6)):
    # Calculate mean importance and sort features
    mean_importance = importance_df['mean_importance']
    sorted_idx = mean_importance.argsort()[::-1]
    top_features = importance_df.iloc[sorted_idx[:top_n]]
    imp_cols = [f for f in importance_df if 'importance_fold' in f]
    # Prepare data for scatter plot
    feature_names = top_features['feature_name']
    importance_values = top_features[imp_cols].values.T  # Transpose for plotting

    # Calculate median importance
    median_importance = top_features['median_importance']

    # Create scatter plot
    fig, ax = plt.subplots(figsize=figsize)

    for i, feature in enumerate(feature_names):
        ax.scatter([i] * importance_values.shape[0], importance_values[:, i],
                   alpha=0.6, label=feature)

    # Plot median line
    ax.plot(range(top_n), median_importance, color='red', linestyle='--',
            linewidth=2, label='Median')

    # Add value labels on the median line
    for i, v in enumerate(median_importance):
        ax.text(i, v, f'{v:.3f}', ha='center', va='bottom', fontweight='bold')

    ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=12)
    ax.set_title(f'Top {top_n} Feature Importances Across Folds with Median', fontsize=14)
    ax.set_xticks(range(top_n))
    ax.set_xticklabels(feature_names, rotation=45, ha='right')
#     ax.legend(title='Features', bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plot_feature_importances_scatter(exp_obj.feature_importance)

# %% [markdown]
# ### Save manual object on W&B as Artifact

# %%
if MANUAL_EXP:
    wandb.init(entity = 'alpha-hunters', project = 'algotrading-project')
    obj_artifact = wandb.Artifact(artifact_name, 'manual_experiment', metadata = exp_metadata)
    obj_artifact.add_file(local_path=exp_obj.store_name+'.zip', name=exp_obj.store_name+'.zip')
    wandb.log_artifact(obj_artifact)
# Out:
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241029_134532-svnni9aq</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/svnni9aq' target="_blank">daily-sky-239</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/svnni9aq' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/svnni9aq</a>

# %%
if MANUAL_EXP:
    wandb.finish()
# Out:
#  View run <strong style="color:#cdcd00">daily-sky-239</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/svnni9aq' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/svnni9aq</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241029_134532-svnni9aq/logs</code>

# %% [markdown]
# ## Save imp_features (when we have RANDOM features)

# %%
if MANUAL_EXP:
    upload_imp_features = True
    symbol = man_params[model_type]['target_symbol']
    trade_mode = man_params[model_type]['trade_mode']
    look_ahead = man_params[model_type]['trg_look_ahead']
    take_profit = man_params[model_type]['trg_take_profit']
    stop_loss = man_params[model_type]['trg_stop_loss']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-0806ae8ed2e2> in <cell line: 1>()
#       3     symbol = man_params[model_type]['target_symbol']
#       4     trade_mode = man_params[model_type]['trade_mode']
# ----> 5     look_ahead = man_params[model_type]['look_ahead']
#       6     take_profit = man_params[model_type]['take_profit']
#       7     stop_loss = man_params[model_type]['stop_loss']
#
# KeyError: 'look_ahead'

# %%
if MANUAL_EXP and upload_imp_features :
    print('save_imp_features ')
    import pickle as pkl
    the_name = f"df_feature_imp_{trade_mode}_{symbol}_M{look_ahead}_TP{take_profit}_SL{stop_loss}.pkl"
    file = open(the_name, 'wb')
    pkl.dump(exp_obj.feature_importance,file)
    file.close()

    imp_artifact_name = artifact_name + '_imp_features'
    wandb.init(entity = 'alpha-hunters', project = 'algotrading-project', job_type="feature_selection")
    imp_artifact = wandb.Artifact(imp_artifact_name, 'feature_selection', metadata = exp_metadata)
    imp_artifact.add_file(local_path = the_name,name = the_name)
    print(f"--> dataset size MB: {imp_artifact.size / 1000000}")
    wandb.log_artifact(imp_artifact)
    wandb.finish()

# %% [markdown]
# # 2. Sweep Experiment using W&B

# %%
sweep_configs = {}
sweep_configs['RF'] = {
    "method": "grid",
#     "metric": {"name": "class 1 f0.03_score_train", "goal": "maximize"},
#     'description':description,
    "parameters": {
        'model_name' : {"values": ['RF']},

        'target_symbol' : {"values": ['EURUSD']},
        'trade_mode' : {"values": ['long']},
        "trg_look_ahead": {"values": [120]},
        "trg_take_profit": {"values": [12]},
        "trg_stop_loss": {"values": [5]},

        "strg_look_ahead": {"values": [120]},
        "strg_take_profit": {"values": [12]},
        "strg_stop_loss": {"values": [5]},

        'save_model_mode' : {"values": ['last_train_size']}, # None, 'sample_train_size', 'last_train_size', 'all_data',
        'imp_features' : {"values": [None]},  #  can be set to imp_features or None
        'n_rand_features': {"values": [None]},
        "early_stopping_rounds" :{"values": [None]},
        "n_splits" : {"values": [17]},
        "max_train_size": {"values": [500*288]},
        'test_size' : {"values": [30*288]},
        'train_test_gap' : {"values": [0]},


        'n_estimators' : {"values": [200]},
        'max_depth': {"values": [5,12]},
        'max_features' : {"values": [30, 50,80]},
        'max_samples' : {"values": [0.2,0.3,0.4]},
        'class_weight':{'values':[0.13,0.15, 0.18, 0.23]},
        'n_jobs': {"values": [-1]},
        'random_state' : {"values": [42]},

#         "objective": {"values": ["binary:logistic"]},

#         "max_depth": {"values": [2, 5, 8, 15, 20, 30]},
#         "learning_rate": {"distribution": "uniform", "min": 0.005, "max": 0.01},
#         "n_estimators": {"distribution": "int_uniform", "min": 50, "max": 300},
#         "min_child_weight": {"distribution": "uniform", "min": 0, "max": 1}, # Used to control over-fitting.
#         "subsample": {"distribution": "uniform", "min": 0.3, "max": 0.5 } ,#Lower values make the algorithm more conservative and prevents overfitting but too small values might lead to under-fitting.


#         "early_stopping_rounds" :{"distribution": "int_uniform", "min": 5, "max": 150},
#         "early_stopping_rounds" :{"values": [40,200]},
#         "gamma": {"distribution": "uniform", "min": 0, "max": 15}, #? float
#         "max_delta_step": {"distribution": "uniform", "min": 0, "max": 15}, #?float
#         "colsample_bytree": {"distribution": "uniform", "min": 0.5, "max": 0.75},
#         "reg_lambda": {"distribution": "uniform", "min": 0, "max": 10},
#         "reg_alpha": {"distribution": "uniform", "min": 0, "max": 10},
#         "train_data_precent": {"distribution": "uniform", "min": 0, "max": 0.98},
#         "train_data_precent": {"distribution": "uniform", "min": 0.5, "max": 0.95},
    },
}

# %%
sweep_configs['XGB'] = {
    "method": "grid",

    "parameters": {
        'model_name' : {"values": ['XGB']},

        'target_symbol' : {"values": ['EURUSD']}, # ["EURUSD","USDCAD","USDJPY","EURJPY","GBPUSD","XAUUSD"]
        'trade_mode' : {"values": ['long']}, # "long", "short"
        "trg_look_ahead": {"values": [300]},
        "trg_take_profit": {"values": [35]},
        "trg_stop_loss": {"values": [5]},

        "strg_look_ahead": {"values": [480]},
        "strg_take_profit": {"values": [40]},
        "strg_stop_loss": {"values": [15]},

        'n_rand_features': {"values": [None]}, # None or Number
        'save_model_mode' : {"values": [None]}, # None, 'sample_train_size', 'last_train_size', 'all_data',

        "early_stopping_rounds" :{"values": [None]}, #None or Number
        'n_splits' : {"values":[3]},
        'max_train_size' : {"values":[400*288,300*288]},
        'test_size' : {"values":[30*288]},
        'train_test_gap' : {"values": [0]},

        "objective": {"values": ["binary:logistic"]},
        "max_depth": {"values": [4,5]},
        "learning_rate": {"values": [0.1,0.01,0.05]},
        'tree_method': {"values": [None]}, #'hist', None
        'device' : {"values": ["cpu"]}, # 'cuda', None
#         "learning_rate": {"distribution": "log_uniform", "min": 1e-5, "max": 5e-1},
        "n_estimators": {"values": [100]},
#         "early_stopping_rounds" :{"distribution": "int_uniform", "min": 5, "max": 150},
#         "early_stopping_rounds" :{"values": [40,200]},
#         "gamma": {"distribution": "uniform", "min": 0, "max": 15}, #? float
        "min_child_weight": {"values": [1]}, # Used to control over-fitting.
#         "max_delta_step": {"distribution": "uniform", "min": 0, "max": 15}, #?float
        "subsample": {"values": [0.3,0.5,0.8]},#Lower values make the algorithm more conservative and prevents overfitting but too small values might lead to under-fitting.
        "colsample_bytree": {"values": [0.5,0.8]},
        "reg_lambda": {"values": [0,0.02,0.1]},
#         "reg_alpha": {"distribution": "uniform", "min": 0, "max": 10},
        "scale_pos_weight" : {"values": [1]},#[1,0.95,1.1]
        'random_state': {"values":[42]},
        },
}

# %%
# %%time

sweep_id = wandb.sweep(
    sweep_configs[model_type],
    entity = 'alpha-hunters',
    project = 'algotrading-project'
)

#!!!!!!!!!!!! SWEEP ID !!!!!!!!!!!!!!!!!
wandb.agent(sweep_id = sweep_id, function = main, entity = 'alpha-hunters',project = 'algotrading-project')
wandb.finish()
# Out:
# Create sweep with ID: vgexp7jx
# Sweep URL: https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx
# wandb: Agent Starting Run: jpzyvjxy with config:
# wandb: 	colsample_bytree: 0.5
# wandb: 	device: cpu
# wandb: 	early_stopping_rounds: None
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 4
# wandb: 	max_train_size: 115200
# wandb: 	min_child_weight: 1
# wandb: 	model_name: XGB
# wandb: 	n_estimators: 100
# wandb: 	n_rand_features: None
# wandb: 	n_splits: 3
# wandb: 	objective: binary:logistic
# wandb: 	random_state: 42
# wandb: 	reg_lambda: 0
# wandb: 	save_model_mode: None
# wandb: 	scale_pos_weight: 1
# wandb: 	strg_look_ahead: 480
# wandb: 	strg_stop_loss: 15
# wandb: 	strg_take_profit: 40
# wandb: 	subsample: 0.3
# wandb: 	target_symbol: EURUSD
# wandb: 	test_size: 8640
# wandb: 	trade_mode: long
# wandb: 	train_test_gap: 0
# wandb: 	tree_method: None
# wandb: 	trg_look_ahead: 300
# wandb: 	trg_stop_loss: 5
# wandb: 	trg_take_profit: 35
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241029_150005-jpzyvjxy</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/jpzyvjxy' target="_blank">leafy-sweep-1</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View sweep at <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/jpzyvjxy' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/jpzyvjxy</a>
# Final Parameters of the Model: {'colsample_bytree': 0.5, 'device': 'cpu', 'early_stopping_rounds': None, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'objective': 'binary:logistic', 'random_state': 42, 'reg_lambda': 0, 'scale_pos_weight': 1, 'subsample': 0.3, 'tree_method': None}
# Dataset file not found at: /kaggle/input/algotrading-project/dataset.parquet
# Len all columns in dataframe is 180
# Len read columns is 180
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP35_SL5 has been generated in 2.81 seconds
# df shape:  (135289, 181)
# ==============================
# --> df final shape: (135289, 180)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-10-28 21:55:00
# --> number of unique days: 135289
# ==============================
# Fold 0:
# --> fold train size: (83449, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.32       0.92    0.19  602  51  80306  2490
# 1   valid  0      0.00       0.00    0.00    0  11   8426   203
# 2    test  0      0.01       0.02    0.00    1  45   8354   240
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-02-19 21:55:00            5.5             NaN
# 1 2024-02-19 22:00:00 2024-04-01 21:55:00            5.5           -5.28
# 2 2024-04-01 22:00:00 2024-05-13 21:55:00            5.5           31.14
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1   -7.34             3               9
# 2  -18.21             5              15
# Fold 1:
# --> fold train size: (100729, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 3   train  1      0.26       0.95    0.15  539  29  97164  2997
# 4   valid  1      0.00       0.00    0.00    0   0   8450   190
# 5    test  1      0.00       0.00    0.00    0   0   8447   193
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-05-13 21:55:00            8.3             NaN
# 4 2024-05-13 22:00:00 2024-06-24 21:55:00            8.3             0.0
# 5 2024-06-24 22:00:00 2024-08-05 21:55:00            8.3             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4     0.0             0             NaN
# 5     0.0             0             NaN
# Fold 2:
# --> fold train size: (115200, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP      TN    FN  \
# 6   train  2      0.27       0.94    0.16  597  40  111407  3156
# 7   valid  2      0.00       0.00    0.00    0   0    8474   166
# 8    test  2      0.00       0.00    0.00    0   0    8445   195
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-23 22:00:00 2024-08-05 21:55:00            8.1             NaN
# 7 2024-08-05 22:00:00 2024-09-16 21:55:00            8.1             0.0
# 8 2024-09-16 22:00:00 2024-10-28 21:55:00            8.1             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7     0.0             0             NaN
# 8     0.0             0             NaN
# CV loop ends
# {'profit_percent_val': -5.28, 'max_dd_val': -7.34, 'profit_percent_test': 31.14, 'max_dd_test': -18.21}
# object stored as pickle: XGB_long_EURUSD_M300_TP35_SL5_prof31.14_max_dd-18.21_median_sig0.00_date2024-10-29_15:00.pkl
# object pickle stored zipped: XGB_long_EURUSD_M300_TP35_SL5_prof31.14_max_dd-18.21_median_sig0.00_date2024-10-29_15:00.pkl
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>f1_score_ex0_test</td><td>▁</td></tr><tr><td>f1_score_ex0_train</td><td>▁</td></tr><tr><td>f1_score_ex0_valid</td><td>▁</td></tr><tr><td>f1_score_ex0_valid&test</td><td>▁</td></tr><tr><td>max_dd_mean_test</td><td>▁</td></tr><tr><td>max_dd_mean_valid</td><td>▁</td></tr><tr><td>max_dd_mean_valid&test</td><td>▁</td></tr><tr><td>max_dd_median_test</td><td>▁</td></tr><tr><td>max_dd_median_valid</td><td>▁</td></tr><tr><td>max_dd_median_valid&test</td><td>▁</td></tr><tr><td>max_dd_min_test</td><td>▁</td></tr><tr><td>max_dd_min_valid</td><td>▁</td></tr><tr><td>max_dd_min_valid&test</td><td>▁</td></tr><tr><td>max_dd_test</td><td>▁</td></tr><tr><td>max_dd_val</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_max_test</td><td>▁</td></tr><tr><td>n_unique_days_max_valid</td><td>▁</td></tr><tr><td>n_unique_days_max_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_mean_test</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_median_test</td><td>▁</td></tr><tr><td>n_unique_days_median_valid</td><td>▁</td></tr><tr><td>n_unique_days_median_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_min_test</td><td>▁</td></tr><tr><td>n_unique_days_min_valid</td><td>▁</td></tr><tr><td>n_unique_days_min_valid&test</td><td>▁</td></tr><tr><td>precision_mean_ex0_test</td><td>▁</td></tr><tr><td>precision_mean_ex0_train</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_median_ex0_test</td><td>▁</td></tr><tr><td>precision_median_ex0_train</td><td>▁</td></tr><tr><td>precision_median_ex0_valid</td><td>▁</td></tr><tr><td>precision_median_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_ex0_test</td><td>▁</td></tr><tr><td>precision_min_ex0_train</td><td>▁</td></tr><tr><td>precision_min_ex0_valid</td><td>▁</td></tr><tr><td>precision_min_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_test</td><td>▁</td></tr><tr><td>precision_min_train</td><td>▁</td></tr><tr><td>precision_min_valid</td><td>▁</td></tr><tr><td>precision_min_valid&test</td><td>▁</td></tr><tr><td>precision_total_test</td><td>▁</td></tr><tr><td>precision_total_train</td><td>▁</td></tr><tr><td>precision_total_valid</td><td>▁</td></tr><tr><td>precision_total_valid&test</td><td>▁</td></tr><tr><td>profit_percent_mean_test</td><td>▁</td></tr><tr><td>profit_percent_mean_valid</td><td>▁</td></tr><tr><td>profit_percent_mean_valid&test</td><td>▁</td></tr><tr><td>profit_percent_median_test</td><td>▁</td></tr><tr><td>profit_percent_median_valid</td><td>▁</td></tr><tr><td>profit_percent_median_valid&test</td><td>▁</td></tr><tr><td>profit_percent_min_test</td><td>▁</td></tr><tr><td>profit_percent_min_valid</td><td>▁</td></tr><tr><td>profit_percent_min_valid&test</td><td>▁</td></tr><tr><td>profit_percent_test</td><td>▁</td></tr><tr><td>profit_percent_val</td><td>▁</td></tr><tr><td>recall_test</td><td>▁</td></tr><tr><td>recall_train</td><td>▁</td></tr><tr><td>recall_valid</td><td>▁</td></tr><tr><td>recall_valid&test</td><td>▁</td></tr><tr><td>signal_count_mean_test</td><td>▁</td></tr><tr><td>signal_count_mean_train</td><td>▁</td></tr><tr><td>signal_count_mean_valid</td> ...
#  View run <strong style="color:#cdcd00">leafy-sweep-1</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/jpzyvjxy' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/jpzyvjxy</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 4 other file(s)
# Find logs at: <code>./wandb/run-20241029_150005-jpzyvjxy/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 18qove21 with config:
# wandb: 	colsample_bytree: 0.5
# wandb: 	device: cpu
# wandb: 	early_stopping_rounds: None
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 4
# wandb: 	max_train_size: 115200
# wandb: 	min_child_weight: 1
# wandb: 	model_name: XGB
# wandb: 	n_estimators: 100
# wandb: 	n_rand_features: None
# wandb: 	n_splits: 3
# wandb: 	objective: binary:logistic
# wandb: 	random_state: 42
# wandb: 	reg_lambda: 0
# wandb: 	save_model_mode: None
# wandb: 	scale_pos_weight: 1
# wandb: 	strg_look_ahead: 480
# wandb: 	strg_stop_loss: 15
# wandb: 	strg_take_profit: 40
# wandb: 	subsample: 0.5
# wandb: 	target_symbol: EURUSD
# wandb: 	test_size: 8640
# wandb: 	trade_mode: long
# wandb: 	train_test_gap: 0
# wandb: 	tree_method: None
# wandb: 	trg_look_ahead: 300
# wandb: 	trg_stop_loss: 5
# wandb: 	trg_take_profit: 35
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241029_150106-18qove21</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/18qove21' target="_blank">lucky-sweep-2</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View sweep at <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/18qove21' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/18qove21</a>
# Final Parameters of the Model: {'colsample_bytree': 0.5, 'device': 'cpu', 'early_stopping_rounds': None, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'objective': 'binary:logistic', 'random_state': 42, 'reg_lambda': 0, 'scale_pos_weight': 1, 'subsample': 0.5, 'tree_method': None}
# Dataset file not found at: /kaggle/input/algotrading-project/dataset.parquet
# Len all columns in dataframe is 180
# Len read columns is 180
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP35_SL5 has been generated in 2.16 seconds
# df shape:  (135289, 181)
# ==============================
# --> df final shape: (135289, 180)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-10-28 21:55:00
# --> number of unique days: 135289
# ==============================
# Fold 0:
# --> fold train size: (83449, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.31       0.94    0.19  574  36  80321  2518
# 1   valid  0      0.00       0.00    0.00    0  27   8410   203
# 2    test  0      0.00       0.00    0.00    0  42   8357   241
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-02-19 21:55:00            6.7             NaN
# 1 2024-02-19 22:00:00 2024-04-01 21:55:00            6.7          -30.26
# 2 2024-04-01 22:00:00 2024-05-13 21:55:00            6.7          -23.57
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1  -29.05             1              27
# 2  -22.25             3              32
# Fold 1:
# --> fold train size: (100729, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 3   train  1      0.24       0.95    0.14  495  25  97168  3041
# 4   valid  1      0.00       0.00    0.00    0   0   8450   190
# 5    test  1      0.00       0.00    0.00    0   0   8447   193
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-05-13 21:55:00            6.1             NaN
# 4 2024-05-13 22:00:00 2024-06-24 21:55:00            6.1             0.0
# 5 2024-06-24 22:00:00 2024-08-05 21:55:00            6.1             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4     0.0             0             NaN
# 5     0.0             0             NaN
# Fold 2:
# --> fold train size: (115200, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP      TN    FN  \
# 6   train  2       0.3       0.92    0.18  679  60  111387  3074
# 7   valid  2       0.0       0.00    0.00    0   0    8474   166
# 8    test  2       0.0       0.00    0.00    0   0    8445   195
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-23 22:00:00 2024-08-05 21:55:00            9.0             NaN
# 7 2024-08-05 22:00:00 2024-09-16 21:55:00            9.0             0.0
# 8 2024-09-16 22:00:00 2024-10-28 21:55:00            9.0             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7     0.0             0             NaN
# 8     0.0             0             NaN
# CV loop ends
# {'profit_percent_val': -30.26, 'max_dd_val': -29.05, 'profit_percent_test': -23.57, 'max_dd_test': -22.25}
# object stored as pickle: XGB_long_EURUSD_M300_TP35_SL5_prof-23.57_max_dd-22.25_median_sig0.00_date2024-10-29_15:01.pkl
# object pickle stored zipped: XGB_long_EURUSD_M300_TP35_SL5_prof-23.57_max_dd-22.25_median_sig0.00_date2024-10-29_15:01.pkl
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>f1_score_ex0_test</td><td>▁</td></tr><tr><td>f1_score_ex0_train</td><td>▁</td></tr><tr><td>f1_score_ex0_valid</td><td>▁</td></tr><tr><td>f1_score_ex0_valid&test</td><td>▁</td></tr><tr><td>max_dd_mean_test</td><td>▁</td></tr><tr><td>max_dd_mean_valid</td><td>▁</td></tr><tr><td>max_dd_mean_valid&test</td><td>▁</td></tr><tr><td>max_dd_median_test</td><td>▁</td></tr><tr><td>max_dd_median_valid</td><td>▁</td></tr><tr><td>max_dd_median_valid&test</td><td>▁</td></tr><tr><td>max_dd_min_test</td><td>▁</td></tr><tr><td>max_dd_min_valid</td><td>▁</td></tr><tr><td>max_dd_min_valid&test</td><td>▁</td></tr><tr><td>max_dd_test</td><td>▁</td></tr><tr><td>max_dd_val</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_max_test</td><td>▁</td></tr><tr><td>n_unique_days_max_valid</td><td>▁</td></tr><tr><td>n_unique_days_max_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_mean_test</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_median_test</td><td>▁</td></tr><tr><td>n_unique_days_median_valid</td><td>▁</td></tr><tr><td>n_unique_days_median_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_min_test</td><td>▁</td></tr><tr><td>n_unique_days_min_valid</td><td>▁</td></tr><tr><td>n_unique_days_min_valid&test</td><td>▁</td></tr><tr><td>precision_mean_ex0_test</td><td>▁</td></tr><tr><td>precision_mean_ex0_train</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_median_ex0_test</td><td>▁</td></tr><tr><td>precision_median_ex0_train</td><td>▁</td></tr><tr><td>precision_median_ex0_valid</td><td>▁</td></tr><tr><td>precision_median_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_ex0_test</td><td>▁</td></tr><tr><td>precision_min_ex0_train</td><td>▁</td></tr><tr><td>precision_min_ex0_valid</td><td>▁</td></tr><tr><td>precision_min_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_test</td><td>▁</td></tr><tr><td>precision_min_train</td><td>▁</td></tr><tr><td>precision_min_valid</td><td>▁</td></tr><tr><td>precision_min_valid&test</td><td>▁</td></tr><tr><td>precision_total_test</td><td>▁</td></tr><tr><td>precision_total_train</td><td>▁</td></tr><tr><td>precision_total_valid</td><td>▁</td></tr><tr><td>precision_total_valid&test</td><td>▁</td></tr><tr><td>profit_percent_mean_test</td><td>▁</td></tr><tr><td>profit_percent_mean_valid</td><td>▁</td></tr><tr><td>profit_percent_mean_valid&test</td><td>▁</td></tr><tr><td>profit_percent_median_test</td><td>▁</td></tr><tr><td>profit_percent_median_valid</td><td>▁</td></tr><tr><td>profit_percent_median_valid&test</td><td>▁</td></tr><tr><td>profit_percent_min_test</td><td>▁</td></tr><tr><td>profit_percent_min_valid</td><td>▁</td></tr><tr><td>profit_percent_min_valid&test</td><td>▁</td></tr><tr><td>profit_percent_test</td><td>▁</td></tr><tr><td>profit_percent_val</td><td>▁</td></tr><tr><td>recall_test</td><td>▁</td></tr><tr><td>recall_train</td><td>▁</td></tr><tr><td>recall_valid</td><td>▁</td></tr><tr><td>recall_valid&test</td><td>▁</td></tr><tr><td>signal_count_mean_test</td><td>▁</td></tr><tr><td>signal_count_mean_train</td><td>▁</td></tr><tr><td>signal_count_mean_valid</td> ...
#  View run <strong style="color:#cdcd00">lucky-sweep-2</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/18qove21' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/18qove21</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 4 other file(s)
# Find logs at: <code>./wandb/run-20241029_150106-18qove21/logs</code>
# wandb: Agent Starting Run: eimuw5t0 with config:
# wandb: 	colsample_bytree: 0.5
# wandb: 	device: cpu
# wandb: 	early_stopping_rounds: None
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 4
# wandb: 	max_train_size: 115200
# wandb: 	min_child_weight: 1
# wandb: 	model_name: XGB
# wandb: 	n_estimators: 100
# wandb: 	n_rand_features: None
# wandb: 	n_splits: 3
# wandb: 	objective: binary:logistic
# wandb: 	random_state: 42
# wandb: 	reg_lambda: 0
# wandb: 	save_model_mode: None
# wandb: 	scale_pos_weight: 1
# wandb: 	strg_look_ahead: 480
# wandb: 	strg_stop_loss: 15
# wandb: 	strg_take_profit: 40
# wandb: 	subsample: 0.8
# wandb: 	target_symbol: EURUSD
# wandb: 	test_size: 8640
# wandb: 	trade_mode: long
# wandb: 	train_test_gap: 0
# wandb: 	tree_method: None
# wandb: 	trg_look_ahead: 300
# wandb: 	trg_stop_loss: 5
# wandb: 	trg_take_profit: 35
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241029_150157-eimuw5t0</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/eimuw5t0' target="_blank">vague-sweep-3</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View sweep at <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/eimuw5t0' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/eimuw5t0</a>
# Final Parameters of the Model: {'colsample_bytree': 0.5, 'device': 'cpu', 'early_stopping_rounds': None, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'objective': 'binary:logistic', 'random_state': 42, 'reg_lambda': 0, 'scale_pos_weight': 1, 'subsample': 0.8, 'tree_method': None}
# Dataset file not found at: /kaggle/input/algotrading-project/dataset.parquet
# Len all columns in dataframe is 180
# Len read columns is 180
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP35_SL5 has been generated in 3.77 seconds
# df shape:  (135289, 181)
# ==============================
# --> df final shape: (135289, 180)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-10-28 21:55:00
# --> number of unique days: 135289
# ==============================
# Fold 0:
# --> fold train size: (83449, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.32       0.94    0.19  590  36  80321  2502
# 1   valid  0      0.00       0.00    0.00    0   5   8432   203
# 2    test  0      0.00       0.00    0.00    0   2   8397   241
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-02-19 21:55:00            5.8             NaN
# 1 2024-02-19 22:00:00 2024-04-01 21:55:00            5.8           -8.50
# 2 2024-04-01 22:00:00 2024-05-13 21:55:00            5.8           -0.18
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1   -6.92             2               3
# 2   -0.18             1               2
# Fold 1:
# --> fold train size: (100729, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 3   train  1      0.27       0.95    0.16  551  26  97167  2985
# 4   valid  1      0.00       0.00    0.00    0   3   8447   190
# 5    test  1      0.00       0.00    0.00    0   2   8445   193
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-05-13 21:55:00            8.2             NaN
# 4 2024-05-13 22:00:00 2024-06-24 21:55:00            8.2           -4.59
# 5 2024-06-24 22:00:00 2024-08-05 21:55:00            8.2           -3.40
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4   -3.44             1               3
# 5   -1.73             1               2
# Fold 2:
# --> fold train size: (115200, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP      TN    FN  \
# 6   train  2      0.28       0.95    0.16  613  31  111416  3140
# 7   valid  2      0.00       0.00    0.00    0   0    8474   166
# 8    test  2      0.00       0.00    0.00    0   0    8445   195
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-23 22:00:00 2024-08-05 21:55:00            9.0             NaN
# 7 2024-08-05 22:00:00 2024-09-16 21:55:00            9.0             0.0
# 8 2024-09-16 22:00:00 2024-10-28 21:55:00            9.0             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7     0.0             0             NaN
# 8     0.0             0             NaN
# CV loop ends
# {'profit_percent_val': -13.09, 'max_dd_val': -11.59, 'profit_percent_test': -3.58, 'max_dd_test': -3.58}
# object stored as pickle: XGB_long_EURUSD_M300_TP35_SL5_prof-3.58_max_dd-3.58_median_sig2.00_date2024-10-29_15:02.pkl
# object pickle stored zipped: XGB_long_EURUSD_M300_TP35_SL5_prof-3.58_max_dd-3.58_median_sig2.00_date2024-10-29_15:02.pkl
# VBox(children=(Label(value='2.096 MB of 2.096 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>f1_score_ex0_test</td><td>▁</td></tr><tr><td>f1_score_ex0_train</td><td>▁</td></tr><tr><td>f1_score_ex0_valid</td><td>▁</td></tr><tr><td>f1_score_ex0_valid&test</td><td>▁</td></tr><tr><td>max_dd_mean_test</td><td>▁</td></tr><tr><td>max_dd_mean_valid</td><td>▁</td></tr><tr><td>max_dd_mean_valid&test</td><td>▁</td></tr><tr><td>max_dd_median_test</td><td>▁</td></tr><tr><td>max_dd_median_valid</td><td>▁</td></tr><tr><td>max_dd_median_valid&test</td><td>▁</td></tr><tr><td>max_dd_min_test</td><td>▁</td></tr><tr><td>max_dd_min_valid</td><td>▁</td></tr><tr><td>max_dd_min_valid&test</td><td>▁</td></tr><tr><td>max_dd_test</td><td>▁</td></tr><tr><td>max_dd_val</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_max_test</td><td>▁</td></tr><tr><td>n_unique_days_max_valid</td><td>▁</td></tr><tr><td>n_unique_days_max_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_mean_test</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_median_test</td><td>▁</td></tr><tr><td>n_unique_days_median_valid</td><td>▁</td></tr><tr><td>n_unique_days_median_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_min_test</td><td>▁</td></tr><tr><td>n_unique_days_min_valid</td><td>▁</td></tr><tr><td>n_unique_days_min_valid&test</td><td>▁</td></tr><tr><td>precision_mean_ex0_test</td><td>▁</td></tr><tr><td>precision_mean_ex0_train</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_median_ex0_test</td><td>▁</td></tr><tr><td>precision_median_ex0_train</td><td>▁</td></tr><tr><td>precision_median_ex0_valid</td><td>▁</td></tr><tr><td>precision_median_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_ex0_test</td><td>▁</td></tr><tr><td>precision_min_ex0_train</td><td>▁</td></tr><tr><td>precision_min_ex0_valid</td><td>▁</td></tr><tr><td>precision_min_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_test</td><td>▁</td></tr><tr><td>precision_min_train</td><td>▁</td></tr><tr><td>precision_min_valid</td><td>▁</td></tr><tr><td>precision_min_valid&test</td><td>▁</td></tr><tr><td>precision_total_test</td><td>▁</td></tr><tr><td>precision_total_train</td><td>▁</td></tr><tr><td>precision_total_valid</td><td>▁</td></tr><tr><td>precision_total_valid&test</td><td>▁</td></tr><tr><td>profit_percent_mean_test</td><td>▁</td></tr><tr><td>profit_percent_mean_valid</td><td>▁</td></tr><tr><td>profit_percent_mean_valid&test</td><td>▁</td></tr><tr><td>profit_percent_median_test</td><td>▁</td></tr><tr><td>profit_percent_median_valid</td><td>▁</td></tr><tr><td>profit_percent_median_valid&test</td><td>▁</td></tr><tr><td>profit_percent_min_test</td><td>▁</td></tr><tr><td>profit_percent_min_valid</td><td>▁</td></tr><tr><td>profit_percent_min_valid&test</td><td>▁</td></tr><tr><td>profit_percent_test</td><td>▁</td></tr><tr><td>profit_percent_val</td><td>▁</td></tr><tr><td>recall_test</td><td>▁</td></tr><tr><td>recall_train</td><td>▁</td></tr><tr><td>recall_valid</td><td>▁</td></tr><tr><td>recall_valid&test</td><td>▁</td></tr><tr><td>signal_count_mean_test</td><td>▁</td></tr><tr><td>signal_count_mean_train</td><td>▁</td></tr><tr><td>signal_count_mean_valid</td> ...
#  View run <strong style="color:#cdcd00">vague-sweep-3</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/eimuw5t0' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/eimuw5t0</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 4 other file(s)
# Find logs at: <code>./wandb/run-20241029_150157-eimuw5t0/logs</code>
# wandb: Ctrl + C detected. Stopping sweep.
# CPU times: user 2min 24s, sys: 2.65 s, total: 2min 26s
# Wall time: 2min 46s

# %%
# Import necessary libraries
import wandb

# The sweep ID should be the same as the one you started with
# Resume the sweep
wandb.agent(sweep_id=sweep_id, function=main, entity='alpha-hunters', project='algotrading-project')

# Finish the sweep
wandb.finish()
# Out:
# wandb: Agent Starting Run: qgzjojnv with config:
# wandb: 	colsample_bytree: 0.5
# wandb: 	device: cpu
# wandb: 	early_stopping_rounds: None
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 4
# wandb: 	max_train_size: 115200
# wandb: 	min_child_weight: 1
# wandb: 	model_name: XGB
# wandb: 	n_estimators: 100
# wandb: 	n_rand_features: None
# wandb: 	n_splits: 3
# wandb: 	objective: binary:logistic
# wandb: 	random_state: 42
# wandb: 	reg_lambda: 0.02
# wandb: 	save_model_mode: None
# wandb: 	scale_pos_weight: 1
# wandb: 	strg_look_ahead: 480
# wandb: 	strg_stop_loss: 15
# wandb: 	strg_take_profit: 40
# wandb: 	subsample: 0.3
# wandb: 	target_symbol: EURUSD
# wandb: 	test_size: 8640
# wandb: 	trade_mode: long
# wandb: 	train_test_gap: 0
# wandb: 	tree_method: None
# wandb: 	trg_look_ahead: 300
# wandb: 	trg_stop_loss: 5
# wandb: 	trg_take_profit: 35
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241029_150333-qgzjojnv</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/qgzjojnv' target="_blank">bright-sweep-4</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View sweep at <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/qgzjojnv' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/qgzjojnv</a>
# Final Parameters of the Model: {'colsample_bytree': 0.5, 'device': 'cpu', 'early_stopping_rounds': None, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'objective': 'binary:logistic', 'random_state': 42, 'reg_lambda': 0.02, 'scale_pos_weight': 1, 'subsample': 0.3, 'tree_method': None}
# Dataset file not found at: /kaggle/input/algotrading-project/dataset.parquet
# Len all columns in dataframe is 180
# Len read columns is 180
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP35_SL5 has been generated in 2.78 seconds
# df shape:  (135289, 181)
# ==============================
# --> df final shape: (135289, 180)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-10-28 21:55:00
# --> number of unique days: 135289
# ==============================
# Fold 0:
# --> fold train size: (83449, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.35       0.93    0.21  656  50  80307  2436
# 1   valid  0      0.00       0.00    0.00    0  48   8389   203
# 2    test  0      0.00       0.00    0.00    0   0   8399   241
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-02-19 21:55:00            5.4             NaN
# 1 2024-02-19 22:00:00 2024-04-01 21:55:00            5.4          -64.09
# 2 2024-04-01 22:00:00 2024-05-13 21:55:00            5.4            0.00
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1  -63.47             2              43
# 2    0.00             0             NaN
# Fold 1:
# --> fold train size: (100729, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 3   train  1      0.25       0.95    0.14  501  26  97167  3035
# 4   valid  1      0.00       0.00    0.00    0   0   8450   190
# 5    test  1      0.00       0.00    0.00    0   0   8447   193
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-05-13 21:55:00            8.3             NaN
# 4 2024-05-13 22:00:00 2024-06-24 21:55:00            8.3             0.0
# 5 2024-06-24 22:00:00 2024-08-05 21:55:00            8.3             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4     0.0             0             NaN
# 5     0.0             0             NaN
# Fold 2:
# --> fold train size: (115200, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP      TN    FN  \
# 6   train  2      0.27       0.92    0.16  586  48  111399  3167
# 7   valid  2      0.00       0.00    0.00    0   0    8474   166
# 8    test  2      0.00       0.00    0.00    0   0    8445   195
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-23 22:00:00 2024-08-05 21:55:00            7.7             NaN
# 7 2024-08-05 22:00:00 2024-09-16 21:55:00            7.7             0.0
# 8 2024-09-16 22:00:00 2024-10-28 21:55:00            7.7             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7     0.0             0             NaN
# 8     0.0             0             NaN
# CV loop ends
# {'profit_percent_val': -64.09, 'max_dd_val': -63.47, 'profit_percent_test': 0, 'max_dd_test': 0}
# /content/ML-Algotrading-Project/utils/evaluation_utils.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   f"precision_total_{set_name}": evals_df.TP.sum() / (evals_df.TP.sum() + evals_df.FP.sum()),
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# object stored as pickle: XGB_long_EURUSD_M300_TP35_SL5_prof0.00_max_dd0.00_median_sig0.00_date2024-10-29_15:04.pkl
# object pickle stored zipped: XGB_long_EURUSD_M300_TP35_SL5_prof0.00_max_dd0.00_median_sig0.00_date2024-10-29_15:04.pkl
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>f1_score_ex0_train</td><td>▁</td></tr><tr><td>f1_score_ex0_valid</td><td>▁</td></tr><tr><td>f1_score_ex0_valid&test</td><td>▁</td></tr><tr><td>max_dd_mean_test</td><td>▁</td></tr><tr><td>max_dd_mean_valid</td><td>▁</td></tr><tr><td>max_dd_mean_valid&test</td><td>▁</td></tr><tr><td>max_dd_median_test</td><td>▁</td></tr><tr><td>max_dd_median_valid</td><td>▁</td></tr><tr><td>max_dd_median_valid&test</td><td>▁</td></tr><tr><td>max_dd_min_test</td><td>▁</td></tr><tr><td>max_dd_min_valid</td><td>▁</td></tr><tr><td>max_dd_min_valid&test</td><td>▁</td></tr><tr><td>max_dd_test</td><td>▁</td></tr><tr><td>max_dd_val</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_max_test</td><td>▁</td></tr><tr><td>n_unique_days_max_valid</td><td>▁</td></tr><tr><td>n_unique_days_max_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_mean_test</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_median_test</td><td>▁</td></tr><tr><td>n_unique_days_median_valid</td><td>▁</td></tr><tr><td>n_unique_days_median_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_min_test</td><td>▁</td></tr><tr><td>n_unique_days_min_valid</td><td>▁</td></tr><tr><td>n_unique_days_min_valid&test</td><td>▁</td></tr><tr><td>precision_mean_ex0_train</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_median_ex0_train</td><td>▁</td></tr><tr><td>precision_median_ex0_valid</td><td>▁</td></tr><tr><td>precision_median_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_ex0_train</td><td>▁</td></tr><tr><td>precision_min_ex0_valid</td><td>▁</td></tr><tr><td>precision_min_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_test</td><td>▁</td></tr><tr><td>precision_min_train</td><td>▁</td></tr><tr><td>precision_min_valid</td><td>▁</td></tr><tr><td>precision_min_valid&test</td><td>▁</td></tr><tr><td>precision_total_train</td><td>▁</td></tr><tr><td>precision_total_valid</td><td>▁</td></tr><tr><td>precision_total_valid&test</td><td>▁</td></tr><tr><td>profit_percent_mean_test</td><td>▁</td></tr><tr><td>profit_percent_mean_valid</td><td>▁</td></tr><tr><td>profit_percent_mean_valid&test</td><td>▁</td></tr><tr><td>profit_percent_median_test</td><td>▁</td></tr><tr><td>profit_percent_median_valid</td><td>▁</td></tr><tr><td>profit_percent_median_valid&test</td><td>▁</td></tr><tr><td>profit_percent_min_test</td><td>▁</td></tr><tr><td>profit_percent_min_valid</td><td>▁</td></tr><tr><td>profit_percent_min_valid&test</td><td>▁</td></tr><tr><td>profit_percent_test</td><td>▁</td></tr><tr><td>profit_percent_val</td><td>▁</td></tr><tr><td>recall_test</td><td>▁</td></tr><tr><td>recall_train</td><td>▁</td></tr><tr><td>recall_valid</td><td>▁</td></tr><tr><td>recall_valid&test</td><td>▁</td></tr><tr><td>signal_count_mean_test</td><td>▁</td></tr><tr><td>signal_count_mean_train</td><td>▁</td></tr><tr><td>signal_count_mean_valid</td><td>▁</td></tr><tr><td>signal_count_mean_valid&test</td><td>▁</td></tr><tr><td>signal_count_median_test</td><td>▁</td></tr><tr><td>signal_count_median_train</td><td>▁</td></tr><tr><td>signal_count_median_valid</td><td>▁</td></tr><tr><td>signal_count_median_valid&test</td><td>▁</td></tr><tr><td>signal_count_min_test</td><td>▁</td></tr><tr><td>signal_count_min_train</td><td>▁</td></tr><tr><td>signal_count_min_valid</td><td>▁</td></tr><tr><td>signal_count_mi ...
#  View run <strong style="color:#cdcd00">bright-sweep-4</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/qgzjojnv' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/qgzjojnv</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 4 other file(s)
# Find logs at: <code>./wandb/run-20241029_150333-qgzjojnv/logs</code>
# wandb: Agent Starting Run: 3y8bywzc with config:
# wandb: 	colsample_bytree: 0.5
# wandb: 	device: cpu
# wandb: 	early_stopping_rounds: None
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 4
# wandb: 	max_train_size: 115200
# wandb: 	min_child_weight: 1
# wandb: 	model_name: XGB
# wandb: 	n_estimators: 100
# wandb: 	n_rand_features: None
# wandb: 	n_splits: 3
# wandb: 	objective: binary:logistic
# wandb: 	random_state: 42
# wandb: 	reg_lambda: 0.02
# wandb: 	save_model_mode: None
# wandb: 	scale_pos_weight: 1
# wandb: 	strg_look_ahead: 480
# wandb: 	strg_stop_loss: 15
# wandb: 	strg_take_profit: 40
# wandb: 	subsample: 0.5
# wandb: 	target_symbol: EURUSD
# wandb: 	test_size: 8640
# wandb: 	trade_mode: long
# wandb: 	train_test_gap: 0
# wandb: 	tree_method: None
# wandb: 	trg_look_ahead: 300
# wandb: 	trg_stop_loss: 5
# wandb: 	trg_take_profit: 35
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241029_150424-3y8bywzc</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/3y8bywzc' target="_blank">visionary-sweep-5</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View sweep at <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/vgexp7jx</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/3y8bywzc' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/3y8bywzc</a>
# Final Parameters of the Model: {'colsample_bytree': 0.5, 'device': 'cpu', 'early_stopping_rounds': None, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'objective': 'binary:logistic', 'random_state': 42, 'reg_lambda': 0.02, 'scale_pos_weight': 1, 'subsample': 0.5, 'tree_method': None}
# Dataset file not found at: /kaggle/input/algotrading-project/dataset.parquet
# Len all columns in dataframe is 180
# Len read columns is 180
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP35_SL5 has been generated in 1.96 seconds
# df shape:  (135289, 181)
# ==============================
# --> df final shape: (135289, 180)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-10-28 21:55:00
# --> number of unique days: 135289
# ==============================
# Fold 0:
# --> fold train size: (83449, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.33       0.94     0.2  612  39  80318  2480
# 1   valid  0      0.00       0.00     0.0    0  26   8411   203
# 2    test  0      0.00       0.00     0.0    0  65   8334   241
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-02-19 21:55:00            7.3             NaN
# 1 2024-02-19 22:00:00 2024-04-01 21:55:00            7.3          -41.45
# 2 2024-04-01 22:00:00 2024-05-13 21:55:00            7.3          -43.81
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1  -40.44             2              13
# 2  -43.37             3              51
# Fold 1:
# --> fold train size: (100729, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 3   train  1      0.24       0.96    0.14  489  23  97170  3047
# 4   valid  1      0.00       0.00    0.00    0   0   8450   190
# 5    test  1      0.00       0.00    0.00    0   0   8447   193
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-05-13 21:55:00            6.4             NaN
# 4 2024-05-13 22:00:00 2024-06-24 21:55:00            6.4             0.0
# 5 2024-06-24 22:00:00 2024-08-05 21:55:00            6.4             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4     0.0             0             NaN
# 5     0.0             0             NaN
# Fold 2:
# --> fold train size: (115200, 185)
# --> fold valid size: (8640, 185)
# --> fold test size: (8640, 185)
#   dataset  K  f1_score  precision  recall   TP  FP      TN    FN  \
# 6   train  2       0.3       0.93    0.18  682  49  111398  3071
# 7   valid  2       0.0       0.00    0.00    0   0    8474   166
# 8    test  2       0.0       0.00    0.00    0   0    8445   195
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-23 22:00:00 2024-08-05 21:55:00            8.5             NaN
# 7 2024-08-05 22:00:00 2024-09-16 21:55:00            8.5             0.0
# 8 2024-09-16 22:00:00 2024-10-28 21:55:00            8.5             0.0
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7     0.0             0             NaN
# 8     0.0             0             NaN
# CV loop ends
# {'profit_percent_val': -41.45, 'max_dd_val': -40.44, 'profit_percent_test': -43.81, 'max_dd_test': -43.37}
# object stored as pickle: XGB_long_EURUSD_M300_TP35_SL5_prof-43.81_max_dd-43.37_median_sig0.00_date2024-10-29_15:05.pkl
# object pickle stored zipped: XGB_long_EURUSD_M300_TP35_SL5_prof-43.81_max_dd-43.37_median_sig0.00_date2024-10-29_15:05.pkl
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>f1_score_ex0_test</td><td>▁</td></tr><tr><td>f1_score_ex0_train</td><td>▁</td></tr><tr><td>f1_score_ex0_valid</td><td>▁</td></tr><tr><td>f1_score_ex0_valid&test</td><td>▁</td></tr><tr><td>max_dd_mean_test</td><td>▁</td></tr><tr><td>max_dd_mean_valid</td><td>▁</td></tr><tr><td>max_dd_mean_valid&test</td><td>▁</td></tr><tr><td>max_dd_median_test</td><td>▁</td></tr><tr><td>max_dd_median_valid</td><td>▁</td></tr><tr><td>max_dd_median_valid&test</td><td>▁</td></tr><tr><td>max_dd_min_test</td><td>▁</td></tr><tr><td>max_dd_min_valid</td><td>▁</td></tr><tr><td>max_dd_min_valid&test</td><td>▁</td></tr><tr><td>max_dd_test</td><td>▁</td></tr><tr><td>max_dd_val</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_max_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_mean_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_median_valid&test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_test</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid</td><td>▁</td></tr><tr><td>n_max_daily_sig_min_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_max_test</td><td>▁</td></tr><tr><td>n_unique_days_max_valid</td><td>▁</td></tr><tr><td>n_unique_days_max_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_mean_test</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid</td><td>▁</td></tr><tr><td>n_unique_days_mean_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_median_test</td><td>▁</td></tr><tr><td>n_unique_days_median_valid</td><td>▁</td></tr><tr><td>n_unique_days_median_valid&test</td><td>▁</td></tr><tr><td>n_unique_days_min_test</td><td>▁</td></tr><tr><td>n_unique_days_min_valid</td><td>▁</td></tr><tr><td>n_unique_days_min_valid&test</td><td>▁</td></tr><tr><td>precision_mean_ex0_test</td><td>▁</td></tr><tr><td>precision_mean_ex0_train</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid</td><td>▁</td></tr><tr><td>precision_mean_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_median_ex0_test</td><td>▁</td></tr><tr><td>precision_median_ex0_train</td><td>▁</td></tr><tr><td>precision_median_ex0_valid</td><td>▁</td></tr><tr><td>precision_median_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_ex0_test</td><td>▁</td></tr><tr><td>precision_min_ex0_train</td><td>▁</td></tr><tr><td>precision_min_ex0_valid</td><td>▁</td></tr><tr><td>precision_min_ex0_valid&test</td><td>▁</td></tr><tr><td>precision_min_test</td><td>▁</td></tr><tr><td>precision_min_train</td><td>▁</td></tr><tr><td>precision_min_valid</td><td>▁</td></tr><tr><td>precision_min_valid&test</td><td>▁</td></tr><tr><td>precision_total_test</td><td>▁</td></tr><tr><td>precision_total_train</td><td>▁</td></tr><tr><td>precision_total_valid</td><td>▁</td></tr><tr><td>precision_total_valid&test</td><td>▁</td></tr><tr><td>profit_percent_mean_test</td><td>▁</td></tr><tr><td>profit_percent_mean_valid</td><td>▁</td></tr><tr><td>profit_percent_mean_valid&test</td><td>▁</td></tr><tr><td>profit_percent_median_test</td><td>▁</td></tr><tr><td>profit_percent_median_valid</td><td>▁</td></tr><tr><td>profit_percent_median_valid&test</td><td>▁</td></tr><tr><td>profit_percent_min_test</td><td>▁</td></tr><tr><td>profit_percent_min_valid</td><td>▁</td></tr><tr><td>profit_percent_min_valid&test</td><td>▁</td></tr><tr><td>profit_percent_test</td><td>▁</td></tr><tr><td>profit_percent_val</td><td>▁</td></tr><tr><td>recall_test</td><td>▁</td></tr><tr><td>recall_train</td><td>▁</td></tr><tr><td>recall_valid</td><td>▁</td></tr><tr><td>recall_valid&test</td><td>▁</td></tr><tr><td>signal_count_mean_test</td><td>▁</td></tr><tr><td>signal_count_mean_train</td><td>▁</td></tr><tr><td>signal_count_mean_valid</td> ...
#  View run <strong style="color:#cdcd00">visionary-sweep-5</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/3y8bywzc' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/3y8bywzc</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 4 other file(s)
# Find logs at: <code>./wandb/run-20241029_150424-3y8bywzc/logs</code>
# wandb: Agent Starting Run: zzsbvj50 with config:
# wandb: 	colsample_bytree: 0.5
# wandb: 	device: cpu
# wandb: 	early_stopping_rounds: None
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 4
# wandb: 	max_train_size: 115200
# wandb: 	min_child_weight: 1
# wandb: 	model_name: XGB
# wandb: 	n_estimators: 100
# wandb: 	n_rand_features: None
# wandb: 	n_splits: 3
# wandb: 	objective: binary:logistic
# wandb: 	random_state: 42
# wandb: 	reg_lambda: 0.02
# wandb: 	save_model_mode: None
# wandb: 	scale_pos_weight: 1
# wandb: 	strg_look_ahead: 480
# wandb: 	strg_stop_loss: 15
# wandb: 	strg_take_profit: 40
# wandb: 	subsample: 0.8
# wandb: 	target_symbol: EURUSD
# wandb: 	test_size: 8640
# wandb: 	trade_mode: long
# wandb: 	train_test_gap: 0
# wandb: 	tree_method: None
# wandb: 	trg_look_ahead: 300
# wandb: 	trg_stop_loss: 5
# wandb: 	trg_take_profit: 35
# wandb: Ctrl + C detected. Stopping sweep.

# %%
#STOP SWEEP
if not MANUAL_EXP:
    print('Finishing The SWEEP ...')
    print(f'{1/0}')

# %% [markdown]
# # Filter models from W&B

# %%
runs_filter = {'path' : "alpha-hunters/algotrading-project",# /artifacts/experiment/trg_clf_long_EURUSD_M240_TP25_SL10
               "order": "+summary_metrics.profit_percent_test",
    'filters': {"$and": [
#                         {"state":'finished'},
                        {"createdAt":{ '$gte': '2024-06-01' }},
                        {"sweep":'jmw8zpy9'},

                        ########### GENERAL CONFIG #############
                        {"config.target_symbol":'EURUSD'},
                        {"config.trade_mode": 'long'},
#                         {"config.look_ahead": 480},
#                         {"config.strg_take_profit": 40},
#                         {"config.strg_stop_loss": 15},
                        {"config.model_name":'XGB'},
#                         ########### MODEL CONFIG #############
#                         {"config.max_depth": 3 },
#                         {"config.n_estimators": { "$gte": 100 } },
#                         {"config.learning_rate": { "$lt": 1 }},
#                         {"config.random_state": 42 },

                        ########### MODEL METRICS #############
                        {"summary_metrics.profit_percent_test" : { "$gte": 10}},
                        {"summary_metrics.profit_percent_val" : { "$gte": 10}},

                        {"summary_metrics.profit_percent_median_test" : { "$gte": 5}},
                        {"summary_metrics.profit_percent_median_valid" : { "$gte": 5}},

                        {"summary_metrics.max_dd_min_test" : { "$gte":-40}},
                        {"summary_metrics.max_dd_min_valid" : { "$gte":-40}},

                        {"summary_metrics.max_dd_test" : { "$gte":-40}},
                        {"summary_metrics.max_dd_val" : { "$gte":-40}},



                                ]
            }
}
runs=api.runs(**runs_filter)
print(len(runs))

# %%
# wandb.finish()

# %%
import shutil
import os
if os.path.isdir("/content/artifacts"):
    shutil.rmtree("/content/artifacts")
meta_datas=fetch_artifacts(runs_filter)

# %%
objects = read_tracker_objects("/content/artifacts")

# %%
# objects['XGB_long_USDJPY_M300_TP35_SL5_prof531.41_max_dd-56.54_median_sig9.00_date2024-07-08_21:24']['obj'].evals

# %% [markdown]
# ## Selected Models' Config

# %%
import pandas as pd
for i,k in enumerate(objects):
    if i == 0:
        df_config = pd.DataFrame(objects[k]['obj'].config, index = [0])
#         display(df_config)
    else:
        df_config = pd.concat([df_config,pd.DataFrame(objects[k]['obj'].config, index = [0])])
# df_config[['colsample_bytree',
#        'learning_rate', 'trg_look_ahead', 'max_depth', 'max_train_size',
#        'min_child_weight', 'model_name', 'n_estimators', 'save_model_mode', 'scale_pos_weight',
#        'subsample', 'trg_take_profit', 'target_symbol', 'tree_method']]
df_config

# %% [markdown]
# ## Feature Importance

# %%
for i,k in enumerate(objects):
    if i == 0:
        df_imp = objects[k]['obj'].feature_importance
        df_imp.rename(columns = {'importances': f'importances_{i}'}, inplace =True)
    else:

        df_imp = df_imp.merge(objects[k]['obj'].feature_importance.rename(columns = {'importances': f'importances_{i}'}),
                             on = 'feature_name')
imp_cols = [f for f in df_imp.columns if 'importances_' in f]
df_imp['imp_mean'] =df_imp[imp_cols].mean(axis = 1)
df_imp.sort_values('imp_mean', ascending = False)[:30]

# %% [markdown]
# ## Models' Correlation

# %%
import pandas as pd
def cal_corr_tar1_predictions(objects):
    '''Calculate corrilation between models Just for target==1'''
    corr_ls=[]
    for i,n in enumerate(objects):

        val_predictions = objects[n]['obj'].val_predictions
        val_predictions=val_predictions[val_predictions.target==1][['pred_as_val','target']].replace(0, -1)
        corr_ls.append((n,val_predictions))
    print("Total_model_count:", len(corr_ls))

    from sklearn.metrics import matthews_corrcoef
    corr_dict={}
    for i in range(0,len(corr_ls)):
        for j in range(i+1,len(corr_ls)):
            corr_dict[(corr_ls[i][0],corr_ls[j][0])]=matthews_corrcoef(corr_ls[i][1]['pred_as_val'], corr_ls[j][1]['pred_as_val'])


    corr_df=pd.DataFrame([k + (v,) for k, v in corr_dict.items()], columns=['model1', 'model2', 'M_corr'])
    print('combination checked:', corr_df.shape[0])
    corr_df.hist('M_corr')
    return corr_df

corr_df=cal_corr_tar1_predictions(objects)

# %%
# corr_df[corr_df.M_corr<0.7]
corr_df
